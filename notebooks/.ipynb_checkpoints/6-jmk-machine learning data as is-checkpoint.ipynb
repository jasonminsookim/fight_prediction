# %% [markdown]
# # 1.1 Import Libraries and Data

# %%
# Disable Warnings
import warnings
warnings.filterwarnings('ignore')

# General Libraries
import numpy as np
import pandas as pd
import pickle
import category_encoders as ce

# Import plotting libraries
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt 

# Sklearn Specific
from sklearn.model_selection import cross_val_score 
from sklearn.model_selection import cross_validate
from sklearn import preprocessing

# sklearn algos
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB # Naive Bayes
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier # SGD
from sklearn.neural_network import MLPClassifier # neural network (multilayer perceptron)

# Bayesian Hyperparameter optimization
from hyperopt import hp, tpe, fmin, space_eval, Trials

# Import Data
with open('../data/temp_data/data_dicts_v2.pickle', 'rb') as handle:
    data_dicts = pickle.load(handle)

# %% [markdown]
# # 1.2 Functions

# %%
def split_encode_standardize(df):
     # Split features and labels
    
    y = df['result'].astype('int')
    
    
    X = df.iloc[:,4:]
    X = X.drop(['result'], axis = 1)
    X = X.fillna(0)

    # Wrangle 
    X['f_stance'] = X.apply(lambda x: str(x['f_stance']), axis = 1)
    X['o_stance'] = X.apply(lambda x: str(x['o_stance']), axis = 1)

    # Encode categorical data
    ce_binary = ce.BinaryEncoder(cols = ['f_stance','o_stance'])
    X = ce_binary.fit_transform(X, y)
    # Scale features with mean = 0 and sd = 1
    X = preprocessing.scale(X)
    
    return(X,y)

def without_keys(d, keys):
    return {x: d[x] for x in d if x not in keys}

# %% [markdown]
# # 2. Setup Bayesian Hyperparameter Optimization

# %%
def objective_function(params):
    """Objective function to minimize: (1- cross validated test_accuracy_score)"""
    
    h_model = params['model']  # Gets the model name
    del params['model'] # Gets the hyperparameters
    
    # Initialize model with parameters
    if h_model == "RandomForestClassifier":
        model = RandomForestClassifier(**params)
    elif h_model == "KNeighborsClassifier":
        model = KNeighborsClassifier(**params)
    elif h_model == "LogisticRegression":
        model = LogisticRegression(**params)
    elif h_model == "SVC":
        model = svm.SVC(**params)
    elif h_model == "DecisionTreeClassifier":
        model = DecisionTreeClassifier(**params)
    elif h_model == "GaussianNB":
        model = GaussianNB(**params)
    elif h_model == "Perceptron":
        model = Perceptron(**params)
    elif h_model == "SGDClassifier":
        model = SGDClassifier(**params)
    elif h_model == "MLPClassifier":
        model = MLPClassifier(**params)
    
    
    scoring_stats = {'accuracy': 'accuracy',
               'recall': 'recall',
               'precision': 'precision',
               'roc_auc': 'roc_auc'}
    
    avg_scores = cross_validate(model, X, y, cv=5, scoring = scoring_stats)

    cv_accuracy = np.mean(avg_scores['test_accuracy'])
    return(1 - cv_accuracy)

def get_space(model):
    model_name = type(model).__name__
    
            
    if model_name == "LogisticRegression":
        space_dict = {'model': model_name,
                      'dual': hp.choice('dual', [True,False]),
                      'fit_intercept': hp.choice('fit_intercept', [True,False])}
        
    elif model_name == "RandomForestClassifier":
        space_dict = {'model' : model_name,
                      'max_depth': hp.choice('max_depth', range(1,50)),
                      'max_features': hp.choice('max_features', range(1,50)),
                      'n_estimators': hp.choice('n_estimators', range(1,50)),}
        
    elif model_name == "SVC": # Fix space dict
        space_dict = {'model': model_name,
                      'kernel': hp.choice('kernel',['linear','poly','rbf','sigmoid']),
                      'shrinking': hp.choice('shrinking', [True, False])}
        
    elif model_name == "KNeighborsClassifier":
        space_dict = {'model': model_name,
                      'n_neighbors': hp.choice('n_neighbors', range(1,100)),
                      'weights': hp.choice('weights', ['uniform', 'distance']),
                      'algorithm': hp.choice('algorithm', ['auto', 'ball_tree', 'kd_tree', 'brute']),
                      'leaf_size': hp.choice('leaf_size', range(1,60))}
    
    elif model_name == "DecisionTreeClassifier":
        space_dict = {'model': model_name,
                      'criterion': hp.choice('criterion', ['gini','entropy']),
                      'splitter': hp.choice('splitter', ['best','random']),
                      'max_features': hp.choice('max_features', ['auto','sqrt','log2']),
                    }
    
    elif model_name == "GaussianNB":
        space_dict = {'model': model_name,
                      'var_smoothing': hp.uniform('var_smoothing', 1e-15, 1e-3)}
    
    elif model_name == "Perceptron":
        space_dict = {'model': model_name,
                      'alpha': hp.uniform('alpha', 1e-15, 1e-3),
                      'fit_intercept': hp.choice('fit_intercept', [True,False])}
    
    elif model_name == "SGDClassifier":
        space_dict = {'model': model_name,
                      'fit_intercept': hp.choice('fit_intercept', [True,False]),
                      'loss': hp.choice('loss', ['hinge','squared_hinge'])
                     }
    
    elif model_name == "MLPClassifier":
        space_dict = {'model': model_name,
                      'activation': hp.choice('activation ', ['identity','logistic','tanh','relu'])}
    

    return(space_dict)   

def get_max_evals(model_name):
    if model_name == "LogisticRegression":
        num_evals =

# %% [markdown]
# # 3. Initialize Models and Generate Dictionary for Results

# %%
# Initialize models
models = []

blr_clf = LogisticRegression()
rf_clf = RandomForestClassifier()
svm_clf = svm.SVC()
knn_clf = KNeighborsClassifier()
dtree_clf = DecisionTreeClassifier()
nb_clf = GaussianNB()
perc_clf = Perceptron()
sgd_clf = SGDClassifier()
mlp_clf = MLPClassifier()

# add models to a list
models.extend((blr_clf,rf_clf,svm_clf,knn_clf, dtree_clf, nb_clf, perc_clf, sgd_clf, mlp_clf))

# Initialize a dictionary for scores, dataset
score_d = {}
score_d['hyper_opt_par'] = []
score_d['dict_type'] = []
score_d['dataset'] = []
score_d['num_obs'] = []
score_d['model_name'] = []
score_d['accuracy'] = []
score_d['precision'] = []
score_d['recall'] = []
score_d['roc_auc'] = []
score_d['hp_dict'] = []

# %% [markdown]
# # 5. Train and print scores for each model

# %%
cumu_dfs_dict = data_dicts[0]

# %%
fe_cumu_dfs_dict = data_dicts[1]

# %%
test_exact = fe_cumu_dfs_dict['Cumulative Data: 1 Fight Lookback Window']

# %%
dict_key = 1
for data_dict in data_dicts:

    
    df_index = 0
    for key in data_dict:
        df_index += 1

        if (df_index <= 0):
            continue
        
        if dict_key == 1:
            dict_type = "cumu_dfs_dict"
        else:
            dict_type = "ef_cumu_dfs_dict"
        df = data_dict[key].copy()

        dataset = key
        num_obs = df.shape[0]

        X,y = split_encode_standardize(df)

        for model in models:
            model_name = type(model).__name__

            print(model_name)

            space = get_space(model) # Get space
            
           # number_of_evals = get_max_evals(model_name) # get_max_evals from testing
            
            best_h = fmin(fn=objective_function, space=space, algo=tpe.suggest, max_evals=5)
            opt_hp = space_eval(space, best_h)
            
            score_d['hyper_opt_par'].append(opt_hp)

            print(opt_hp)
            del opt_hp['model']

            # create new model with tuned hyperparameters
            if model_name == "RandomForestClassifier":
                ht_model = RandomForestClassifier(**opt_hp)

            elif model_name == "KNeighborsClassifier":
                ht_model = KNeighborsClassifier(**opt_hp)

            elif model_name == "LogisticRegression":
                ht_model = LogisticRegression(**opt_hp)
            elif model_name == "SVC":
                ht_model = svm.SVC(**opt_hp)
            elif model_name == "DecisionTreeClassifier":
                ht_model = DecisionTreeClassifier(**opt_hp)
            elif model_name == "GaussianNB":
                ht_model = GaussianNB(**opt_hp)
            elif model_name == "Perceptron":
                ht_model = Perceptron(**opt_hp)
            elif model_name == "SGDClassifier":
                ht_model = SGDClassifier(**opt_hp)
            elif model_name == "MLPClassifier":
                ht_model = MLPClassifier(**opt_hp)
            
            


            scoring_stats = {'accuracy': 'accuracy',
                   'recall': 'recall',
                   'precision': 'precision',
                   'roc_auc': 'roc_auc'}    



            # Calculate scores
            avg_scores = cross_validate(ht_model, X, y, cv=5, scoring = scoring_stats)

            accuracy = np.mean(avg_scores['test_accuracy'])
            precision = np.mean(avg_scores['test_precision'])
            recall = np.mean(avg_scores['test_recall'])
            roc_auc = np.mean(avg_scores['test_roc_auc'])

            # append to dictionary
            score_d['dict_type'].append(dict_type)
            score_d['dataset'].append(dataset)
            score_d['num_obs'].append(num_obs)
            score_d['model_name'].append(model_name)
            score_d['accuracy'].append(accuracy)
            score_d['precision'].append(precision)
            score_d['recall'].append(recall)
            score_d['roc_auc'].append(roc_auc)
            score_d['hp_dict'].append(opt_hp)
            
    dict_key += 1
# Out:
# LogisticRegression
# 100%|██████████| 5/5 [00:04<00:00,  1.13it/s, best loss: 0.4658656299406907]
# {'dual': True, 'fit_intercept': False, 'model': 'LogisticRegression'}
# RandomForestClassifier
# 100%|██████████| 5/5 [01:03<00:00, 12.51s/it, best loss: 0.4848132052901466]
# {'max_depth': 19, 'max_features': 46, 'model': 'RandomForestClassifier', 'n_estimators': 39}
# SVC
# 100%|██████████| 5/5 [04:10<00:00, 53.20s/it, best loss: 0.47598500121295273]
# {'kernel': 'linear', 'model': 'SVC', 'shrinking': False}
# KNeighborsClassifier
# 100%|██████████| 5/5 [04:04<00:00, 47.99s/it, best loss: 0.4796083835941879]
# {'algorithm': 'kd_tree', 'leaf_size': 49, 'model': 'KNeighborsClassifier', 'n_neighbors': 75, 'weights': 'uniform'}
# DecisionTreeClassifier
# 100%|██████████| 5/5 [00:01<00:00,  3.50it/s, best loss: 0.49233142049304435]
# {'criterion': 'gini', 'max_features': 'log2', 'model': 'DecisionTreeClassifier', 'splitter': 'random'}
# GaussianNB
# 100%|██████████| 5/5 [00:01<00:00,  3.08it/s, best loss: 0.49276473737483584]
# {'model': 'GaussianNB', 'var_smoothing': 0.0006778797837565959}
# Perceptron
# 100%|██████████| 5/5 [00:00<00:00,  7.78it/s, best loss: 0.48929485624419666]
# {'alpha': 0.0006281474581602776, 'fit_intercept': False, 'model': 'Perceptron'}
# SGDClassifier
# 100%|██████████| 5/5 [00:00<00:00,  8.00it/s, best loss: 0.4783078055595058]
# {'fit_intercept': True, 'loss': 'hinge', 'model': 'SGDClassifier'}
# MLPClassifier
# 100%|██████████| 5/5 [01:34<00:00, 18.73s/it, best loss: 0.46948148365023457]
# {'activation': 'identity', 'model': 'MLPClassifier'}
# LogisticRegression
# 100%|██████████| 5/5 [00:02<00:00,  2.40it/s, best loss: 0.46508353328451835]
# {'dual': False, 'fit_intercept': True, 'model': 'LogisticRegression'}
# RandomForestClassifier
# 100%|██████████| 5/5 [00:07<00:00,  1.04s/it, best loss: 0.4976197470258201]
# {'max_depth': 22, 'max_features': 23, 'model': 'RandomForestClassifier', 'n_estimators': 6}
# SVC
# 100%|██████████| 5/5 [01:23<00:00, 16.07s/it, best loss: 0.46244818198906756]
# {'kernel': 'linear', 'model': 'SVC', 'shrinking': True}
# KNeighborsClassifier
# 100%|██████████| 5/5 [03:23<00:00, 43.93s/it, best loss: 0.4833259624839318]
# {'algorithm': 'auto', 'leaf_size': 21, 'model': 'KNeighborsClassifier', 'n_neighbors': 6, 'weights': 'uniform'}
# DecisionTreeClassifier
# 100%|██████████| 5/5 [00:00<00:00,  7.87it/s, best loss: 0.49099829277167506]
# {'criterion': 'gini', 'max_features': 'log2', 'model': 'DecisionTreeClassifier', 'splitter': 'random'}
# GaussianNB
# 100%|██████████| 5/5 [00:01<00:00,  4.92it/s, best loss: 0.4886085684133923]
# {'model': 'GaussianNB', 'var_smoothing': 0.0003660885955083328}
# Perceptron
# 100%|██████████| 5/5 [00:00<00:00, 11.15it/s, best loss: 0.48890882776786526]
# {'alpha': 1.871164808802846e-05, 'fit_intercept': False, 'model': 'Perceptron'}
# SGDClassifier
# 100%|██████████| 5/5 [00:00<00:00,  8.57it/s, best loss: 0.4865065251967191]
# {'fit_intercept': False, 'loss': 'squared_hinge', 'model': 'SGDClassifier'}
# MLPClassifier
# 100%|██████████| 5/5 [00:33<00:00,  7.34s/it, best loss: 0.4690559948024495]
# {'activation': 'identity', 'model': 'MLPClassifier'}
# LogisticRegression
# 100%|██████████| 5/5 [00:01<00:00,  4.19it/s, best loss: 0.4684068299925761]
# {'dual': False, 'fit_intercept': True, 'model': 'LogisticRegression'}
# RandomForestClassifier
# 100%|██████████| 5/5 [00:12<00:00,  2.45s/it, best loss: 0.48222519178421197]
# {'max_depth': 20, 'max_features': 26, 'model': 'RandomForestClassifier', 'n_estimators': 35}
# SVC
# 100%|██████████| 5/5 [00:25<00:00,  5.05s/it, best loss: 0.4621945063103192]
# {'kernel': 'rbf', 'model': 'SVC', 'shrinking': False}
# KNeighborsClassifier
# 100%|██████████| 5/5 [00:46<00:00,  7.43s/it, best loss: 0.4830774560752289]
# {'algorithm': 'ball_tree', 'leaf_size': 53, 'model': 'KNeighborsClassifier', 'n_neighbors': 81, 'weights': 'uniform'}
# DecisionTreeClassifier
# 100%|██████████| 5/5 [00:00<00:00, 10.64it/s, best loss: 0.4742113338282603]
# {'criterion': 'gini', 'max_features': 'sqrt', 'model': 'DecisionTreeClassifier', 'splitter': 'random'}
# GaussianNB
# 100%|██████████| 5/5 [00:00<00:00, 11.76it/s, best loss: 0.48839891116060374]
# {'model': 'GaussianNB', 'var_smoothing': 0.00030063242805267523}
# Perceptron
# 100%|██████████| 5/5 [00:00<00:00, 17.24it/s, best loss: 0.4830863647611977]
# {'alpha': 0.0005576780001937795, 'fit_intercept': True, 'model': 'Perceptron'}
# SGDClassifier
# 100%|██████████| 5/5 [00:00<00:00, 17.18it/s, best loss: 0.46928780004949266]
# {'fit_intercept': False, 'loss': 'squared_hinge', 'model': 'SGDClassifier'}
# MLPClassifier
# 100%|██████████| 5/5 [00:35<00:00,  6.09s/it, best loss: 0.4719574362781489]
# {'activation': 'logistic', 'model': 'MLPClassifier'}
# LogisticRegression
# 100%|██████████| 5/5 [00:00<00:00,  6.74it/s, best loss: 0.43018841390396556]
# {'dual': True, 'fit_intercept': False, 'model': 'LogisticRegression'}
# RandomForestClassifier
# 100%|██████████| 5/5 [00:12<00:00,  2.72s/it, best loss: 0.4785265052154859]
# {'max_depth': 8, 'max_features': 44, 'model': 'RandomForestClassifier', 'n_estimators': 46}
# SVC
# 100%|██████████| 5/5 [00:09<00:00,  1.94s/it, best loss: 0.43761234340967947]
# {'kernel': 'linear', 'model': 'SVC', 'shrinking': True}
# KNeighborsClassifier
# 100%|██████████| 5/5 [00:15<00:00,  3.13s/it, best loss: 0.47558563268408394]
# {'algorithm': 'kd_tree', 'leaf_size': 39, 'model': 'KNeighborsClassifier', 'n_neighbors': 40, 'weights': 'uniform'}
# DecisionTreeClassifier
# 100%|██████████| 5/5 [00:00<00:00, 17.36it/s, best loss: 0.48958831422267135]
# {'criterion': 'gini', 'max_features': 'auto', 'model': 'DecisionTreeClassifier', 'splitter': 'random'}
# GaussianNB
# 100%|██████████| 5/5 [00:00<00:00, 16.07it/s, best loss: 0.4554453371051679]
# {'model': 'GaussianNB', 'var_smoothing': 0.0005483377462628209}
# Perceptron
# 100%|██████████| 5/5 [00:00<00:00, 21.64it/s, best loss: 0.4903427624115151]
# {'alpha': 0.0005941782011845252, 'fit_intercept': False, 'model': 'Perceptron'}
# SGDClassifier
# 100%|██████████| 5/5 [00:00<00:00, 22.22it/s, best loss: 0.46811215720583466]
# {'fit_intercept': False, 'loss': 'squared_hinge', 'model': 'SGDClassifier'}
# MLPClassifier
# 100%|██████████| 5/5 [00:15<00:00,  3.53s/it, best loss: 0.4376617877702941]
# {'activation': 'identity', 'model': 'MLPClassifier'}
# LogisticRegression
# 100%|██████████| 5/5 [00:00<00:00, 14.04it/s, best loss: 0.4475801572897762]
# {'dual': True, 'fit_intercept': False, 'model': 'LogisticRegression'}
# RandomForestClassifier
# 100%|██████████| 5/5 [00:03<00:00,  1.80it/s, best loss: 0.4719600725952813]
# {'max_depth': 11, 'max_features': 2, 'model': 'RandomForestClassifier', 'n_estimators': 49}
# SVC
# 100%|██████████| 5/5 [00:02<00:00,  2.02it/s, best loss: 0.4299153055051421]
# {'kernel': 'linear', 'model': 'SVC', 'shrinking': False}
# KNeighborsClassifier
# 100%|██████████| 5/5 [00:11<00:00,  2.42s/it, best loss: 0.4673018753781004]
# {'algorithm': 'ball_tree', 'leaf_size': 11, 'model': 'KNeighborsClassifier', 'n_neighbors': 3, 'weights': 'uniform'}
# DecisionTreeClassifier
# 100%|██████████| 5/5 [00:00<00:00, 21.83it/s, best loss: 0.46866303690260136]
# {'criterion': 'entropy', 'max_features': 'log2', 'model': 'DecisionTreeClassifier', 'splitter': 'random'}
# GaussianNB
# 100%|██████████| 5/5 [00:00<00:00, 21.64it/s, best loss: 0.4108892921960072]
# {'model': 'GaussianNB', 'var_smoothing': 0.0007290932668574808}
# Perceptron
# 100%|██████████| 5/5 [00:00<00:00, 26.45it/s, best loss: 0.47377495462794916]
# {'alpha': 0.0003589966021818071, 'fit_intercept': False, 'model': 'Perceptron'}
# SGDClassifier
# 100%|██████████| 5/5 [00:00<00:00, 26.73it/s, best loss: 0.4300665456745312]
# {'fit_intercept': False, 'loss': 'hinge', 'model': 'SGDClassifier'}
# MLPClassifier
# 100%|██████████| 5/5 [00:11<00:00,  2.27s/it, best loss: 0.44398064125831804]
# {'activation': 'relu', 'model': 'MLPClassifier'}
# LogisticRegression
# 100%|██████████| 5/5 [00:04<00:00,  1.11it/s, best loss: 0.44387835339584925]
# {'dual': True, 'fit_intercept': True, 'model': 'LogisticRegression'}
# RandomForestClassifier
# 100%|██████████| 5/5 [00:36<00:00,  6.88s/it, best loss: 0.4164091582108529]
# {'max_depth': 7, 'max_features': 4, 'model': 'RandomForestClassifier', 'n_estimators': 29}
# SVC
# 100%|██████████| 5/5 [03:30<00:00, 42.38s/it, best loss: 0.4265354307654986]
# {'kernel': 'rbf', 'model': 'SVC', 'shrinking': False}
# KNeighborsClassifier
# 100%|██████████| 5/5 [04:48<00:00, 57.23s/it, best loss: 0.45357130906870335]
# {'algorithm': 'auto', 'leaf_size': 40, 'model': 'KNeighborsClassifier', 'n_neighbors': 61, 'weights': 'distance'}
# DecisionTreeClassifier
# 100%|██████████| 5/5 [00:01<00:00,  3.75it/s, best loss: 0.46253544749588005]
# {'criterion': 'entropy', 'max_features': 'auto', 'model': 'DecisionTreeClassifier', 'splitter': 'best'}
# GaussianNB
# 100%|██████████| 5/5 [00:01<00:00,  3.31it/s, best loss: 0.4979714412387175]
# {'model': 'GaussianNB', 'var_smoothing': 0.00030908356797528126}
# Perceptron
# 100%|██████████| 5/5 [00:00<00:00,  8.05it/s, best loss: 0.47179153108086636]
# {'alpha': 0.00038815421795080485, 'fit_intercept': False, 'model': 'Perceptron'}
# SGDClassifier
# 100%|██████████| 5/5 [00:00<00:00,  8.04it/s, best loss: 0.4806191077687527]
# {'fit_intercept': True, 'loss': 'squared_hinge', 'model': 'SGDClassifier'}
# MLPClassifier
# 100%|██████████| 5/5 [01:21<00:00, 17.19s/it, best loss: 0.4366489464042227]
# {'activation': 'relu', 'model': 'MLPClassifier'}
# LogisticRegression
# 100%|██████████| 5/5 [00:02<00:00,  2.20it/s, best loss: 0.4582132735185478]
# {'dual': False, 'fit_intercept': True, 'model': 'LogisticRegression'}
# RandomForestClassifier
# 100%|██████████| 5/5 [00:26<00:00,  4.07s/it, best loss: 0.4222442218284993]
# {'max_depth': 10, 'max_features': 47, 'model': 'RandomForestClassifier', 'n_estimators': 48}
# SVC
# 100%|██████████| 5/5 [01:27<00:00, 18.62s/it, best loss: 0.4410118897762699]
# {'kernel': 'rbf', 'model': 'SVC', 'shrinking': False}
# KNeighborsClassifier
# 100%|██████████| 5/5 [01:52<00:00, 20.02s/it, best loss: 0.4637677778809993]
# {'algorithm': 'kd_tree', 'leaf_size': 35, 'model': 'KNeighborsClassifier', 'n_neighbors': 64, 'weights': 'uniform'}
# DecisionTreeClassifier
# 100%|██████████| 5/5 [00:00<00:00,  5.44it/s, best loss: 0.478043009859784]
# {'criterion': 'gini', 'max_features': 'sqrt', 'model': 'DecisionTreeClassifier', 'splitter': 'random'}
# GaussianNB
# 100%|██████████| 5/5 [00:00<00:00,  5.72it/s, best loss: 0.4902133843312424]
# {'model': 'GaussianNB', 'var_smoothing': 0.00012068751838731551}
# Perceptron
# 100%|██████████| 5/5 [00:00<00:00, 11.18it/s, best loss: 0.4923483251244456]
# {'alpha': 0.0007358921882242032, 'fit_intercept': False, 'model': 'Perceptron'}
# SGDClassifier
# 100%|██████████| 5/5 [00:00<00:00,  9.85it/s, best loss: 0.4796313617144362]
# {'fit_intercept': True, 'loss': 'hinge', 'model': 'SGDClassifier'}
# MLPClassifier
# 100%|██████████| 5/5 [00:58<00:00, 11.57s/it, best loss: 0.4232814230942079]
# {'activation': 'relu', 'model': 'MLPClassifier'}
# LogisticRegression
# 100%|██████████| 5/5 [00:01<00:00,  4.32it/s, best loss: 0.4719653551101213]
# {'dual': False, 'fit_intercept': False, 'model': 'LogisticRegression'}
# RandomForestClassifier
# 100%|██████████| 5/5 [00:20<00:00,  4.05s/it, best loss: 0.44485127443702044]
# {'max_depth': 16, 'max_features': 22, 'model': 'RandomForestClassifier', 'n_estimators': 37}
# SVC
# 100%|██████████| 5/5 [00:29<00:00,  6.08s/it, best loss: 0.4497401633259094]
# {'kernel': 'rbf', 'model': 'SVC', 'shrinking': True}
# KNeighborsClassifier
# 100%|██████████| 5/5 [00:30<00:00,  4.77s/it, best loss: 0.44173521405592686]
# {'algorithm': 'kd_tree', 'leaf_size': 13, 'model': 'KNeighborsClassifier', 'n_neighbors': 25, 'weights': 'uniform'}
# DecisionTreeClassifier
# 100%|██████████| 5/5 [00:00<00:00,  7.41it/s, best loss: 0.48308537490720127]
# {'criterion': 'gini', 'max_features': 'sqrt', 'model': 'DecisionTreeClassifier', 'splitter': 'best'}
# GaussianNB
# 100%|██████████| 5/5 [00:00<00:00, 11.99it/s, best loss: 0.48352190051967336]
# {'model': 'GaussianNB', 'var_smoothing': 0.0003630916054772841}
# Perceptron
# 100%|██████████| 5/5 [00:00<00:00, 16.55it/s, best loss: 0.4906666666666666]
# {'alpha': 0.0009113317931777539, 'fit_intercept': False, 'model': 'Perceptron'}
# SGDClassifier
# 100%|██████████| 5/5 [00:00<00:00, 17.42it/s, best loss: 0.47152585993565954]
# {'fit_intercept': False, 'loss': 'hinge', 'model': 'SGDClassifier'}
# MLPClassifier
# 100%|██████████| 5/5 [00:33<00:00,  6.51s/it, best loss: 0.4430457807473398]
# {'activation': 'relu', 'model': 'MLPClassifier'}
# LogisticRegression
# 100%|██████████| 5/5 [00:00<00:00,  6.44it/s, best loss: 0.4168412918329927]
# {'dual': False, 'fit_intercept': False, 'model': 'LogisticRegression'}
# RandomForestClassifier
# 100%|██████████| 5/5 [00:08<00:00,  2.20s/it, best loss: 0.4769983940235931]
# {'max_depth': 47, 'max_features': 31, 'model': 'RandomForestClassifier', 'n_estimators': 37}
# SVC
# 100%|██████████| 5/5 [00:08<00:00,  1.73s/it, best loss: 0.423535475007786]
# {'kernel': 'linear', 'model': 'SVC', 'shrinking': True}
# KNeighborsClassifier
# 100%|██████████| 5/5 [00:15<00:00,  3.18s/it, best loss: 0.4421969208539669]
# {'algorithm': 'auto', 'leaf_size': 9, 'model': 'KNeighborsClassifier', 'n_neighbors': 14, 'weights': 'uniform'}
# DecisionTreeClassifier
# 100%|██████████| 5/5 [00:00<00:00, 13.05it/s, best loss: 0.46442199837116094]
# {'criterion': 'gini', 'max_features': 'sqrt', 'model': 'DecisionTreeClassifier', 'splitter': 'random'}
# GaussianNB
# 100%|██████████| 5/5 [00:00<00:00, 15.52it/s, best loss: 0.462855599807547]
# {'model': 'GaussianNB', 'var_smoothing': 0.00017255246014620648}
# Perceptron
# 100%|██████████| 5/5 [00:00<00:00, 19.86it/s, best loss: 0.49474335115098367]
# {'alpha': 0.0006051079701383717, 'fit_intercept': False, 'model': 'Perceptron'}
# SGDClassifier
# 100%|██████████| 5/5 [00:00<00:00, 22.22it/s, best loss: 0.46133832044640155]
# {'fit_intercept': False, 'loss': 'hinge', 'model': 'SGDClassifier'}
# MLPClassifier
# 100%|██████████| 5/5 [00:15<00:00,  3.56s/it, best loss: 0.42719797507764423]
# {'activation': 'logistic', 'model': 'MLPClassifier'}
# LogisticRegression
# 100%|██████████| 5/5 [00:00<00:00, 13.73it/s, best loss: 0.4333635813672112]
# {'dual': False, 'fit_intercept': True, 'model': 'LogisticRegression'}
# RandomForestClassifier
# 100%|██████████| 5/5 [00:03<00:00,  1.23it/s, best loss: 0.4599818511796733]
# {'max_depth': 40, 'max_features': 5, 'model': 'RandomForestClassifier', 'n_estimators': 30}
# SVC
# 100%|██████████| 5/5 [00:01<00:00,  2.55it/s, best loss: 0.4437689050211736]
# {'kernel': 'linear', 'model': 'SVC', 'shrinking': True}
# KNeighborsClassifier
# 100%|██████████| 5/5 [00:03<00:00,  1.55it/s, best loss: 0.46512401693889893]
# {'algorithm': 'ball_tree', 'leaf_size': 15, 'model': 'KNeighborsClassifier', 'n_neighbors': 40, 'weights': 'uniform'}
# DecisionTreeClassifier
# 100%|██████████| 5/5 [00:00<00:00, 25.37it/s, best loss: 0.4564125831820931]
# {'criterion': 'entropy', 'max_features': 'auto', 'model': 'DecisionTreeClassifier', 'splitter': 'random'}
# GaussianNB
# 100%|██████████| 5/5 [00:00<00:00, 21.83it/s, best loss: 0.4386569872958257]
# {'model': 'GaussianNB', 'var_smoothing': 7.540126939557412e-05}
# Perceptron
# 100%|██████████| 5/5 [00:00<00:00, 25.50it/s, best loss: 0.49304295220810646]
# {'alpha': 0.0003659144495755107, 'fit_intercept': True, 'model': 'Perceptron'}
# SGDClassifier
# 100%|██████████| 5/5 [00:00<00:00, 25.90it/s, best loss: 0.40725952813067157]
# {'fit_intercept': False, 'loss': 'hinge', 'model': 'SGDClassifier'}
# MLPClassifier
# 100%|██████████| 5/5 [00:12<00:00,  2.49s/it, best loss: 0.4317906836055656]
# {'activation': 'relu', 'model': 'MLPClassifier'}
# LogisticRegression
# 100%|██████████| 5/5 [00:06<00:00,  1.25s/it, best loss: 0.46629476422709826]
# {'dual': True, 'fit_intercept': False, 'model': 'LogisticRegression'}
# RandomForestClassifier
# 100%|██████████| 5/5 [00:22<00:00,  5.23s/it, best loss: 0.4861131559355212]
# {'max_depth': 8, 'max_features': 42, 'model': 'RandomForestClassifier', 'n_estimators': 16}
# SVC
# 100%|██████████| 5/5 [04:45<00:00, 58.80s/it, best loss: 0.47020005353722083]
# {'kernel': 'linear', 'model': 'SVC', 'shrinking': True}
# KNeighborsClassifier
# 100%|██████████| 5/5 [38:40<00:00, 534.09s/it, best loss: 0.48639548112394704]
# {'algorithm': 'brute', 'leaf_size': 24, 'model': 'KNeighborsClassifier', 'n_neighbors': 70, 'weights': 'distance'}
# DecisionTreeClassifier
# 100%|██████████| 5/5 [00:01<00:00,  3.43it/s, best loss: 0.4956685042202388]
# {'criterion': 'gini', 'max_features': 'log2', 'model': 'DecisionTreeClassifier', 'splitter': 'best'}
# GaussianNB
# 100%|██████████| 5/5 [00:02<00:00,  1.98it/s, best loss: 0.49146415934015375]
# {'model': 'GaussianNB', 'var_smoothing': 0.0008167526692034373}
# Perceptron
# 100%|██████████| 5/5 [00:00<00:00,  6.57it/s, best loss: 0.48090247860602464]
# {'alpha': 0.0009697849240791764, 'fit_intercept': False, 'model': 'Perceptron'}
# SGDClassifier
# 100%|██████████| 5/5 [00:00<00:00,  6.99it/s, best loss: 0.48726797052106774]
# {'fit_intercept': True, 'loss': 'hinge', 'model': 'SGDClassifier'}
# MLPClassifier
# 100%|██████████| 5/5 [02:11<00:00, 28.42s/it, best loss: 0.46889780246438517]
# {'activation': 'identity', 'model': 'MLPClassifier'}
# LogisticRegression
# 100%|██████████| 5/5 [00:03<00:00,  1.49it/s, best loss: 0.46904653684177255]
# {'dual': False, 'fit_intercept': False, 'model': 'LogisticRegression'}
# RandomForestClassifier
# 100%|██████████| 5/5 [00:06<00:00,  1.32s/it, best loss: 0.48360732813513485]
# {'max_depth': 4, 'max_features': 28, 'model': 'RandomForestClassifier', 'n_estimators': 32}
# SVC
# 100%|██████████| 5/5 [01:41<00:00, 20.20s/it, best loss: 0.47036264356874635]
# {'kernel': 'rbf', 'model': 'SVC', 'shrinking': True}
# KNeighborsClassifier
# 100%|██████████| 5/5 [03:40<00:00, 47.48s/it, best loss: 0.48359473048144785]
# {'algorithm': 'kd_tree', 'leaf_size': 3, 'model': 'KNeighborsClassifier', 'n_neighbors': 64, 'weights': 'distance'}
# DecisionTreeClassifier
# 100%|██████████| 5/5 [00:01<00:00,  4.05it/s, best loss: 0.4870415769322223]
# {'criterion': 'gini', 'max_features': 'sqrt', 'model': 'DecisionTreeClassifier', 'splitter': 'random'}
# GaussianNB
# 100%|██████████| 5/5 [00:01<00:00,  3.02it/s, best loss: 0.48808051815164233]
# {'model': 'GaussianNB', 'var_smoothing': 7.09044663221809e-05}
# Perceptron
# 100%|██████████| 5/5 [00:00<00:00,  7.17it/s, best loss: 0.49446122881835475]
# {'alpha': 0.000729400710995335, 'fit_intercept': False, 'model': 'Perceptron'}
# SGDClassifier
# 100%|██████████| 5/5 [00:00<00:00,  6.98it/s, best loss: 0.48175020920872014]
# {'fit_intercept': True, 'loss': 'hinge', 'model': 'SGDClassifier'}
# MLPClassifier
# 100%|██████████| 5/5 [01:02<00:00, 13.22s/it, best loss: 0.46693013657687743]
# {'activation': 'identity', 'model': 'MLPClassifier'}
# LogisticRegression
# 100%|██████████| 5/5 [00:01<00:00,  2.99it/s, best loss: 0.4612798812175204]
# {'dual': True, 'fit_intercept': False, 'model': 'LogisticRegression'}
# RandomForestClassifier
# 100%|██████████| 5/5 [00:17<00:00,  3.15s/it, best loss: 0.4732947290274685]
# {'max_depth': 34, 'max_features': 20, 'model': 'RandomForestClassifier', 'n_estimators': 45}
# SVC
# 100%|██████████| 5/5 [00:40<00:00,  8.86s/it, best loss: 0.4719524870081664]
# {'kernel': 'linear', 'model': 'SVC', 'shrinking': False}
# KNeighborsClassifier
# 100%|██████████| 5/5 [01:42<00:00, 14.24s/it, best loss: 0.4821806483543678]
# {'algorithm': 'ball_tree', 'leaf_size': 51, 'model': 'KNeighborsClassifier', 'n_neighbors': 6, 'weights': 'distance'}
# DecisionTreeClassifier
# 100%|██████████| 5/5 [00:00<00:00,  9.15it/s, best loss: 0.48887206137094774]
# {'criterion': 'gini', 'max_features': 'sqrt', 'model': 'DecisionTreeClassifier', 'splitter': 'random'}
# GaussianNB
# 100%|██████████| 5/5 [00:00<00:00,  6.78it/s, best loss: 0.4835050730017322]
# {'model': 'GaussianNB', 'var_smoothing': 0.00020191139945112784}
# Perceptron
# 100%|██████████| 5/5 [00:00<00:00, 15.19it/s, best loss: 0.4924305864884929]
# {'alpha': 0.0004332853450150979, 'fit_intercept': False, 'model': 'Perceptron'}
# SGDClassifier
# 100%|██████████| 5/5 [00:00<00:00, 15.52it/s, best loss: 0.47195842613214545]
# {'fit_intercept': True, 'loss': 'hinge', 'model': 'SGDClassifier'}
# MLPClassifier
# 100%|██████████| 5/5 [00:35<00:00,  6.53s/it, best loss: 0.46572828507795105]
# {'activation': 'identity', 'model': 'MLPClassifier'}
# LogisticRegression
# 100%|██████████| 5/5 [00:00<00:00,  4.99it/s, best loss: 0.4406083302468713]
# {'dual': False, 'fit_intercept': True, 'model': 'LogisticRegression'}
# RandomForestClassifier
# 100%|██████████| 5/5 [00:09<00:00,  1.96s/it, best loss: 0.4732891626314033]
# {'max_depth': 2, 'max_features': 9, 'model': 'RandomForestClassifier', 'n_estimators': 28}
# SVC
# 100%|██████████| 5/5 [00:11<00:00,  2.29s/it, best loss: 0.44728603196812633]
# {'kernel': 'sigmoid', 'model': 'SVC', 'shrinking': False}
# KNeighborsClassifier
# 100%|██████████| 5/5 [00:12<00:00,  2.74s/it, best loss: 0.45847418523751526]
# {'algorithm': 'brute', 'leaf_size': 3, 'model': 'KNeighborsClassifier', 'n_neighbors': 26, 'weights': 'uniform'}
# DecisionTreeClassifier
# 100%|██████████| 5/5 [00:00<00:00, 14.45it/s, best loss: 0.4836871104770527]
# {'criterion': 'gini', 'max_features': 'auto', 'model': 'DecisionTreeClassifier', 'splitter': 'random'}
# GaussianNB
# 100%|██████████| 5/5 [00:00<00:00, 14.62it/s, best loss: 0.44428468002152144]
# {'model': 'GaussianNB', 'var_smoothing': 0.0004205563390373325}
# Perceptron
# 100%|██████████| 5/5 [00:00<00:00, 20.83it/s, best loss: 0.4874045419512436]
# {'alpha': 0.0005931700164511804, 'fit_intercept': False, 'model': 'Perceptron'}
# SGDClassifier
# 100%|██████████| 5/5 [00:00<00:00, 21.53it/s, best loss: 0.4636181464664708]
# {'fit_intercept': False, 'loss': 'hinge', 'model': 'SGDClassifier'}
# MLPClassifier
# 100%|██████████| 5/5 [00:21<00:00,  4.49s/it, best loss: 0.4436207985376013]
# {'activation': 'logistic', 'model': 'MLPClassifier'}
# LogisticRegression
# 100%|██████████| 5/5 [00:00<00:00, 11.73it/s, best loss: 0.45108892921960075]
# {'dual': True, 'fit_intercept': False, 'model': 'LogisticRegression'}
# RandomForestClassifier
# 100%|██████████| 5/5 [00:03<00:00,  1.29it/s, best loss: 0.49643073200241983]
# {'max_depth': 18, 'max_features': 30, 'model': 'RandomForestClassifier', 'n_estimators': 7}
# SVC
# 100%|██████████| 5/5 [00:02<00:00,  2.03it/s, best loss: 0.47035692679975805]
# {'kernel': 'poly', 'model': 'SVC', 'shrinking': False}
# KNeighborsClassifier
# 100%|██████████| 5/5 [00:07<00:00,  1.47s/it, best loss: 0.5123714458560193]
# {'algorithm': 'kd_tree', 'leaf_size': 16, 'model': 'KNeighborsClassifier', 'n_neighbors': 30, 'weights': 'uniform'}
# DecisionTreeClassifier
# 100%|██████████| 5/5 [00:00<00:00, 19.70it/s, best loss: 0.46842105263157896]
# {'criterion': 'gini', 'max_features': 'auto', 'model': 'DecisionTreeClassifier', 'splitter': 'random'}
# GaussianNB
# 100%|██████████| 5/5 [00:00<00:00, 20.04it/s, best loss: 0.4265577737447066]
# {'model': 'GaussianNB', 'var_smoothing': 0.0005334378957571275}
# Perceptron
# 100%|██████████| 5/5 [00:00<00:00, 23.90it/s, best loss: 0.47223230490018153]
# {'alpha': 0.00016263159830716092, 'fit_intercept': False, 'model': 'Perceptron'}
# SGDClassifier
# 100%|██████████| 5/5 [00:00<00:00, 25.77it/s, best loss: 0.4564125831820932]
# {'fit_intercept': True, 'loss': 'hinge', 'model': 'SGDClassifier'}
# MLPClassifier
# 100%|██████████| 5/5 [00:12<00:00,  2.41s/it, best loss: 0.4547186932849365]
# {'activation': 'relu', 'model': 'MLPClassifier'}
# LogisticRegression
# 100%|██████████| 5/5 [00:06<00:00,  1.22s/it, best loss: 0.43548953096375365]
# {'dual': False, 'fit_intercept': False, 'model': 'LogisticRegression'}
# RandomForestClassifier
# 100%|██████████| 5/5 [00:56<00:00, 10.41s/it, best loss: 0.41409973816952894]
# {'max_depth': 46, 'max_features': 43, 'model': 'RandomForestClassifier', 'n_estimators': 41}
# SVC
# 100%|██████████| 5/5 [04:35<00:00, 56.80s/it, best loss: 0.421900696820391]
# {'kernel': 'rbf', 'model': 'SVC', 'shrinking': True}
# KNeighborsClassifier
# 100%|██████████| 5/5 [03:35<00:00, 49.08s/it, best loss: 0.44938264892130875]
# {'algorithm': 'ball_tree', 'leaf_size': 3, 'model': 'KNeighborsClassifier', 'n_neighbors': 44, 'weights': 'distance'}
# DecisionTreeClassifier
# 100%|██████████| 5/5 [00:01<00:00,  3.38it/s, best loss: 0.475559631262391]
# {'criterion': 'entropy', 'max_features': 'log2', 'model': 'DecisionTreeClassifier', 'splitter': 'best'}
# GaussianNB
# 100%|██████████| 5/5 [00:02<00:00,  2.43it/s, best loss: 0.46991040880687285]
# {'model': 'GaussianNB', 'var_smoothing': 0.000861604186518753}
# Perceptron
# 100%|██████████| 5/5 [00:00<00:00,  7.07it/s, best loss: 0.4739662715508227]
# {'alpha': 0.0006971328614890131, 'fit_intercept': False, 'model': 'Perceptron'}
# SGDClassifier
# 100%|██████████| 5/5 [00:00<00:00,  7.03it/s, best loss: 0.46774361526814623]
# {'fit_intercept': True, 'loss': 'squared_hinge', 'model': 'SGDClassifier'}
# MLPClassifier
# 100%|██████████| 5/5 [02:11<00:00, 26.09s/it, best loss: 0.43405280944931957]
# {'activation': 'relu', 'model': 'MLPClassifier'}
# LogisticRegression
# 100%|██████████| 5/5 [00:02<00:00,  1.68it/s, best loss: 0.455039368362087]
# {'dual': True, 'fit_intercept': False, 'model': 'LogisticRegression'}
# RandomForestClassifier
# 100%|██████████| 5/5 [00:22<00:00,  5.65s/it, best loss: 0.40717114631844264]
# {'max_depth': 29, 'max_features': 40, 'model': 'RandomForestClassifier', 'n_estimators': 37}
# SVC
# 100%|██████████| 5/5 [01:23<00:00, 16.70s/it, best loss: 0.43704084651270736]
# {'kernel': 'rbf', 'model': 'SVC', 'shrinking': True}
# KNeighborsClassifier
# 100%|██████████| 5/5 [01:33<00:00, 18.98s/it, best loss: 0.45026452758358937]
# {'algorithm': 'brute', 'leaf_size': 53, 'model': 'KNeighborsClassifier', 'n_neighbors': 66, 'weights': 'uniform'}
# DecisionTreeClassifier
# 100%|██████████| 5/5 [00:00<00:00,  6.92it/s, best loss: 0.46826233938003126]
# {'criterion': 'gini', 'max_features': 'auto', 'model': 'DecisionTreeClassifier', 'splitter': 'best'}
# GaussianNB
# 100%|██████████| 5/5 [00:01<00:00,  4.43it/s, best loss: 0.4690479532446341]
# {'model': 'GaussianNB', 'var_smoothing': 0.0007037935731414546}
# Perceptron
# 100%|██████████| 5/5 [00:00<00:00, 11.26it/s, best loss: 0.4807074126888311]
# {'alpha': 0.0006373417002277572, 'fit_intercept': False, 'model': 'Perceptron'}
# SGDClassifier
# 100%|██████████| 5/5 [00:00<00:00, 11.23it/s, best loss: 0.47300674647495045]
# {'fit_intercept': True, 'loss': 'hinge', 'model': 'SGDClassifier'}
# MLPClassifier
# 100%|██████████| 5/5 [01:11<00:00, 14.46s/it, best loss: 0.43253089343591233]
# {'activation': 'relu', 'model': 'MLPClassifier'}
# LogisticRegression
# 100%|██████████| 5/5 [00:01<00:00,  2.92it/s, best loss: 0.4519505073001733]
# {'dual': True, 'fit_intercept': True, 'model': 'LogisticRegression'}
# RandomForestClassifier
# 100%|██████████| 5/5 [00:20<00:00,  4.38s/it, best loss: 0.4475209106656768]
# {'max_depth': 5, 'max_features': 14, 'model': 'RandomForestClassifier', 'n_estimators': 42}
# SVC
# 100%|██████████| 5/5 [00:37<00:00,  6.87s/it, best loss: 0.45459539717891606]
# {'kernel': 'poly', 'model': 'SVC', 'shrinking': True}
# KNeighborsClassifier
# 100%|██████████| 5/5 [00:46<00:00, 10.15s/it, best loss: 0.44352487008166297]
# {'algorithm': 'auto', 'leaf_size': 58, 'model': 'KNeighborsClassifier', 'n_neighbors': 54, 'weights': 'uniform'}
# DecisionTreeClassifier
# 100%|██████████| 5/5 [00:00<00:00, 11.61it/s, best loss: 0.489325414501361]
# {'criterion': 'entropy', 'max_features': 'sqrt', 'model': 'DecisionTreeClassifier', 'splitter': 'random'}
# GaussianNB
# 100%|██████████| 5/5 [00:00<00:00,  7.15it/s, best loss: 0.4737362039099232]
# {'model': 'GaussianNB', 'var_smoothing': 0.0004234001107160263}
# Perceptron
# 100%|██████████| 5/5 [00:00<00:00, 15.57it/s, best loss: 0.48665478841870824]
# {'alpha': 2.83163125558943e-05, 'fit_intercept': False, 'model': 'Perceptron'}
# SGDClassifier
# 100%|██████████| 5/5 [00:00<00:00, 15.48it/s, best loss: 0.45995446671615936]
# {'fit_intercept': True, 'loss': 'hinge', 'model': 'SGDClassifier'}
# MLPClassifier
# 100%|██████████| 5/5 [00:41<00:00,  8.18s/it, best loss: 0.44350111358574607]
# {'activation': 'logistic', 'model': 'MLPClassifier'}
# LogisticRegression
# 100%|██████████| 5/5 [00:01<00:00,  4.36it/s, best loss: 0.4205889325312089]
# {'dual': False, 'fit_intercept': False, 'model': 'LogisticRegression'}
# RandomForestClassifier
# 100%|██████████| 5/5 [00:08<00:00,  1.42s/it, best loss: 0.46294072011352083]
# {'max_depth': 11, 'max_features': 17, 'model': 'RandomForestClassifier', 'n_estimators': 19}
# SVC
# 100%|██████████| 5/5 [00:11<00:00,  2.24s/it, best loss: 0.43024611931373336]
# {'kernel': 'linear', 'model': 'SVC', 'shrinking': True}
# KNeighborsClassifier
# 100%|██████████| 5/5 [00:18<00:00,  3.32s/it, best loss: 0.45705314252646867]
# {'algorithm': 'brute', 'leaf_size': 31, 'model': 'KNeighborsClassifier', 'n_neighbors': 85, 'weights': 'uniform'}
# DecisionTreeClassifier
# 100%|██████████| 5/5 [00:00<00:00, 15.67it/s, best loss: 0.4747842905938353]
# {'criterion': 'gini', 'max_features': 'log2', 'model': 'DecisionTreeClassifier', 'splitter': 'random'}
# GaussianNB
# 100%|██████████| 5/5 [00:00<00:00, 14.04it/s, best loss: 0.45765935924538925]
# {'model': 'GaussianNB', 'var_smoothing': 0.0002157417702613544}
# Perceptron
# 100%|██████████| 5/5 [00:00<00:00, 21.55it/s, best loss: 0.4880848845663178]
# {'alpha': 0.0001981678487660481, 'fit_intercept': False, 'model': 'Perceptron'}
# SGDClassifier
# 100%|██████████| 5/5 [00:00<00:00, 21.36it/s, best loss: 0.4547017613918396]
# {'fit_intercept': True, 'loss': 'squared_hinge', 'model': 'SGDClassifier'}
# MLPClassifier
# 100%|██████████| 5/5 [00:19<00:00,  3.98s/it, best loss: 0.4272721416185661]
# {'activation': 'identity', 'model': 'MLPClassifier'}
# LogisticRegression
# 100%|██████████| 5/5 [00:00<00:00, 11.47it/s, best loss: 0.4963399879007865]
# {'dual': True, 'fit_intercept': True, 'model': 'LogisticRegression'}
# RandomForestClassifier
# 100%|██████████| 5/5 [00:02<00:00,  2.34it/s, best loss: 0.47023593466424685]
# {'max_depth': 46, 'max_features': 46, 'model': 'RandomForestClassifier', 'n_estimators': 22}
# SVC
# 100%|██████████| 5/5 [00:02<00:00,  2.34it/s, best loss: 0.45819721718088335]
# {'kernel': 'poly', 'model': 'SVC', 'shrinking': True}
# KNeighborsClassifier
# 100%|██████████| 5/5 [00:05<00:00,  1.07s/it, best loss: 0.47431941923774956]
# {'algorithm': 'kd_tree', 'leaf_size': 40, 'model': 'KNeighborsClassifier', 'n_neighbors': 18, 'weights': 'distance'}
# DecisionTreeClassifier
# 100%|██████████| 5/5 [00:00<00:00, 20.24it/s, best loss: 0.46500302480338784]
# {'criterion': 'gini', 'max_features': 'auto', 'model': 'DecisionTreeClassifier', 'splitter': 'best'}
# GaussianNB
# 100%|██████████| 5/5 [00:00<00:00, 19.80it/s, best loss: 0.45614035087719296]
# {'model': 'GaussianNB', 'var_smoothing': 0.0004165613097848049}
# Perceptron
# 100%|██████████| 5/5 [00:00<00:00, 26.45it/s, best loss: 0.5017241379310345]
# {'alpha': 2.1091065599249337e-06, 'fit_intercept': True, 'model': 'Perceptron'}
# SGDClassifier
# 100%|██████████| 5/5 [00:00<00:00, 26.59it/s, best loss: 0.44416212946158506]
# {'fit_intercept': False, 'loss': 'squared_hinge', 'model': 'SGDClassifier'}
# MLPClassifier
# 100%|██████████| 5/5 [00:09<00:00,  1.86s/it, best loss: 0.4441923774954628]
# {'activation': 'tanh', 'model': 'MLPClassifier'}

# %%
scores_dict = without_keys(score_d, 'hp_dict')
scores_df = pd.DataFrame(scores_dict)
scores_df
# Out:
#                                          hyper_opt_par         dict_type  \
# 0               {'dual': True, 'fit_intercept': False}     cumu_dfs_dict
# 1    {'max_depth': 19, 'max_features': 46, 'n_estim...     cumu_dfs_dict
# 2             {'kernel': 'linear', 'shrinking': False}     cumu_dfs_dict
# 3    {'algorithm': 'kd_tree', 'leaf_size': 49, 'n_n...     cumu_dfs_dict
# 4    {'criterion': 'gini', 'max_features': 'log2', ...     cumu_dfs_dict
# 5             {'var_smoothing': 0.0006778797837565959}     cumu_dfs_dict
# 6    {'alpha': 0.0006281474581602776, 'fit_intercep...     cumu_dfs_dict
# 7             {'fit_intercept': True, 'loss': 'hinge'}     cumu_dfs_dict
# 8                           {'activation': 'identity'}     cumu_dfs_dict
# 9               {'dual': False, 'fit_intercept': True}     cumu_dfs_dict
# 10   {'max_depth': 22, 'max_features': 23, 'n_estim...     cumu_dfs_dict
# 11             {'kernel': 'linear', 'shrinking': True}     cumu_dfs_dict
# 12   {'algorithm': 'auto', 'leaf_size': 21, 'n_neig...     cumu_dfs_dict
# 13   {'criterion': 'gini', 'max_features': 'log2', ...     cumu_dfs_dict
# 14            {'var_smoothing': 0.0003660885955083328}     cumu_dfs_dict
# 15   {'alpha': 1.871164808802846e-05, 'fit_intercep...     cumu_dfs_dict
# 16   {'fit_intercept': False, 'loss': 'squared_hinge'}     cumu_dfs_dict
# 17                          {'activation': 'identity'}     cumu_dfs_dict
# 18              {'dual': False, 'fit_intercept': True}     cumu_dfs_dict
# 19   {'max_depth': 20, 'max_features': 26, 'n_estim...     cumu_dfs_dict
# 20               {'kernel': 'rbf', 'shrinking': False}     cumu_dfs_dict
# 21   {'algorithm': 'ball_tree', 'leaf_size': 53, 'n...     cumu_dfs_dict
# 22   {'criterion': 'gini', 'max_features': 'sqrt', ...     cumu_dfs_dict
# 23           {'var_smoothing': 0.00030063242805267523}     cumu_dfs_dict
# 24   {'alpha': 0.0005576780001937795, 'fit_intercep...     cumu_dfs_dict
# 25   {'fit_intercept': False, 'loss': 'squared_hinge'}     cumu_dfs_dict
# 26                          {'activation': 'logistic'}     cumu_dfs_dict
# 27              {'dual': True, 'fit_intercept': False}     cumu_dfs_dict
# 28   {'max_depth': 8, 'max_features': 44, 'n_estima...     cumu_dfs_dict
# 29             {'kernel': 'linear', 'shrinking': True}     cumu_dfs_dict
# ..                                                 ...               ...
# 150  {'alpha': 0.0006373417002277572, 'fit_intercep...  ef_cumu_dfs_dict
# 151           {'fit_intercept': True, 'loss': 'hinge'}  ef_cumu_dfs_dict
# 152                             {'activation': 'relu'}  ef_cumu_dfs_dict
# 153              {'dual': True, 'fit_intercept': True}  ef_cumu_dfs_dict
# 154  {'max_depth': 5, 'max_features': 14, 'n_estima...  ef_cumu_dfs_dict
# 155              {'kernel': 'poly', 'shrinking': True}  ef_cumu_dfs_dict
# 156  {'algorithm': 'auto', 'leaf_size': 58, 'n_neig...  ef_cumu_dfs_dict
# 157  {'criterion': 'entropy', 'max_features': 'sqrt...  ef_cumu_dfs_dict
# 158           {'var_smoothing': 0.0004234001107160263}  ef_cumu_dfs_dict
# 159  {'alpha': 2.83163125558943e-05, 'fit_intercept...  ef_cumu_dfs_dict
# 160           {'fit_intercept': True, 'loss': 'hinge'}  ef_cumu_dfs_dict
# 161                         {'activation': 'logistic'}  ef_cumu_dfs_dict
# 162            {'dual': False, 'fit_intercept': False}  ef_cumu_dfs_dict
# 163  {'max_depth': 11, 'max_features': 17, 'n_estim...  ef_cumu_dfs_dict
# 164            {'kernel': 'linear', 'shrinking': True}  ef_cumu_dfs_dict
# 165  {'algorithm': 'brute', 'leaf_size': 31, 'n_nei...  ef_cumu_dfs_dict
# 166  {'criterion': 'gini', 'max_features': 'log2', ...  ef_cumu_dfs_dict
# 167           {'var_smoothing': 0.0002157417702613544}  ef_cumu_dfs_dict
# 168  {'alpha': 0.0001981678487660481, 'fit_intercep...  ef_cumu_dfs_dict
# 169   {'fit_intercept': True, 'loss': 'squared_hinge'}  ef_cumu_dfs_dict
# 170                         {'activation': 'identity'}  ef_cumu_dfs_dict
# 171              {'dual': True, 'fit_intercept': True}  ef_cumu_dfs_dict
# 172  {'max_depth': 46, 'max_features': 46, 'n_estim...  ef_cumu_dfs_dict
# 173              {'kernel': 'poly', 'shrinking': True}  ef_cumu_dfs_dict
# 174  {'algorithm': 'kd_tree', 'leaf_size': 40, 'n_n...  ef_cumu_dfs_dict
# 175  {'criterion': 'gini', 'max_features': 'auto', ...  ef_cumu_dfs_dict
# 176           {'var_smoothing': 0.0004165613097848049}  ef_cumu_dfs_dict
# 177  {'alpha': 2.1091065599249337e-06, 'fit_interce...  ef_cumu_dfs_dict
# 178  {'fit_intercept': False, 'loss': 'squared_hinge'}  ef_cumu_dfs_dict
# 179                             {'activation': 'tanh'}  ef_cumu_dfs_dict
#
#                                        dataset  num_obs  \
# 0          Exact Data: 1 Fight Lookback Window     6914
# 1          Exact Data: 1 Fight Lookback Window     6914
# 2          Exact Data: 1 Fight Lookback Window     6914
# 3          Exact Data: 1 Fight Lookback Window     6914
# 4          Exact Data: 1 Fight Lookback Window     6914
# 5          Exact Data: 1 Fight Lookback Window     6914
# 6          Exact Data: 1 Fight Lookback Window     6914
# 7          Exact Data: 1 Fight Lookback Window     6914
# 8          Exact Data: 1 Fight Lookback Window     6914
# 9          Exact Data: 3 Fight Lookback Window     3780
# 10         Exact Data: 3 Fight Lookback Window     3780
# 11         Exact Data: 3 Fight Lookback Window     3780
# 12         Exact Data: 3 Fight Lookback Window     3780
# 13         Exact Data: 3 Fight Lookback Window     3780
# 14         Exact Data: 3 Fight Lookback Window     3780
# 15         Exact Data: 3 Fight Lookback Window     3780
# 16         Exact Data: 3 Fight Lookback Window     3780
# 17         Exact Data: 3 Fight Lookback Window     3780
# 18         Exact Data: 5 Fight Lookback Window     2248
# 19         Exact Data: 5 Fight Lookback Window     2248
# 20         Exact Data: 5 Fight Lookback Window     2248
# 21         Exact Data: 5 Fight Lookback Window     2248
# 22         Exact Data: 5 Fight Lookback Window     2248
# 23         Exact Data: 5 Fight Lookback Window     2248
# 24         Exact Data: 5 Fight Lookback Window     2248
# 25         Exact Data: 5 Fight Lookback Window     2248
# 26         Exact Data: 5 Fight Lookback Window     2248
# 27         Exact Data: 7 Fight Lookback Window     1348
# 28         Exact Data: 7 Fight Lookback Window     1348
# 29         Exact Data: 7 Fight Lookback Window     1348
# ..                                         ...      ...
# 150   Cumulative Data: 3 Fight Lookback Window     3780
# 151   Cumulative Data: 3 Fight Lookback Window     3780
# 152   Cumulative Data: 3 Fight Lookback Window     3780
# 153   Cumulative Data: 5 Fight Lookback Window     2248
# 154   Cumulative Data: 5 Fight Lookback Window     2248
# 155   Cumulative Data: 5 Fight Lookback Window     2248
# 156   Cumulative Data: 5 Fight Lookback Window     2248
# 157   Cumulative Data: 5 Fight Lookback Window     2248
# 158   Cumulative Data: 5 Fight Lookback Window     2248
# 159   Cumulative Data: 5 Fight Lookback Window     2248
# 160   Cumulative Data: 5 Fight Lookback Window     2248
# 161   Cumulative Data: 5 Fight Lookback Window     2248
# 162   Cumulative Data: 7 Fight Lookback Window     1348
# 163   Cumulative Data: 7 Fight Lookback Window     1348
# 164   Cumulative Data: 7 Fight Lookback Window     1348
# 165   Cumulative Data: 7 Fight Lookback Window     1348
# 166   Cumulative Data: 7 Fight Lookback Window     1348
# 167   Cumulative Data: 7 Fight Lookback Window     1348
# 168   Cumulative Data: 7 Fight Lookback Window     1348
# 169   Cumulative Data: 7 Fight Lookback Window     1348
# 170   Cumulative Data: 7 Fight Lookback Window     1348
# 171  Cumulative Data: 10 Fight Lookback Window      572
# 172  Cumulative Data: 10 Fight Lookback Window      572
# 173  Cumulative Data: 10 Fight Lookback Window      572
# 174  Cumulative Data: 10 Fight Lookback Window      572
# 175  Cumulative Data: 10 Fight Lookback Window      572
# 176  Cumulative Data: 10 Fight Lookback Window      572
# 177  Cumulative Data: 10 Fight Lookback Window      572
# 178  Cumulative Data: 10 Fight Lookback Window      572
# 179  Cumulative Data: 10 Fight Lookback Window      572
#
#                  model_name  accuracy  precision    recall   roc_auc
# 0        LogisticRegression  0.531531   0.523686  0.527937  0.541079
# 1    RandomForestClassifier  0.511712   0.504339  0.486182  0.520659
# 2                       SVC  0.524015   0.520267  0.437104  0.533964
# 3      KNeighborsClassifier  0.520392   0.514082  0.457073  0.519940
# 4    DecisionTreeClassifier  0.501444   0.493532  0.492655  0.501306
# 5                GaussianNB  0.507235   0.500029  0.700762  0.527431
# 6                Perceptron  0.510705   0.503544  0.524108  0.516493
# 7             SGDClassifier  0.487414   0.475908  0.428820  0.482435
# 8             MLPClassifier  0.524583   0.519993  0.450928  0.535765
# 9        LogisticRegression  0.534916   0.528913  0.497597  0.542696
# 10   RandomForestClassifier  0.505817   0.496462  0.382991  0.501737
# 11                      SVC  0.537552   0.533160  0.502440  0.545224
# 12     KNeighborsClassifier  0.516674   0.512189  0.345379  0.517501
# 13   DecisionTreeClassifier  0.503961   0.495752  0.510487  0.504079
# 14               GaussianNB  0.511391   0.506382  0.809980  0.520178
# 15               Perceptron  0.511091   0.505030  0.531478  0.504391
# 16            SGDClassifier  0.509776   0.502142  0.554056  0.514505
# 17            MLPClassifier  0.531740   0.524624  0.506195  0.540466
# 18       LogisticRegression  0.531593   0.524754  0.503167  0.547796
# 19   RandomForestClassifier  0.512465   0.504219  0.494118  0.498698
# 20                      SVC  0.537805   0.533499  0.472398  0.544669
# 21     KNeighborsClassifier  0.516923   0.510056  0.439819  0.505089
# 22   DecisionTreeClassifier  0.510689   0.502758  0.473303  0.510089
# 23               GaussianNB  0.511601   0.508160  0.788235  0.532943
# 24               Perceptron  0.516914   0.506028  0.515837  0.528721
# 25            SGDClassifier  0.510674   0.500948  0.558371  0.511199
# 26            MLPClassifier  0.527593   0.519896  0.516742  0.544542
# 27       LogisticRegression  0.563875   0.552559  0.571907  0.579749
# 28   RandomForestClassifier  0.510338   0.500986  0.450752  0.517597
# 29                      SVC  0.562388   0.553732  0.528161  0.581831
# ..                      ...       ...        ...       ...       ...
# 150              Perceptron  0.519293   0.509928  0.547039  0.526683
# 151           SGDClassifier  0.511636   0.503967  0.528283  0.524727
# 152           MLPClassifier  0.571159   0.563652  0.565345  0.600769
# 153      LogisticRegression  0.544046   0.536819  0.526697  0.564474
# 154  RandomForestClassifier  0.535124   0.530493  0.456109  0.550280
# 155                     SVC  0.545405   0.557989  0.356561  0.560216
# 156    KNeighborsClassifier  0.556475   0.555949  0.477828  0.570207
# 157  DecisionTreeClassifier  0.496890   0.487318  0.476923  0.496561
# 158              GaussianNB  0.526264   0.516033  0.800000  0.573621
# 159              Perceptron  0.513345   0.504353  0.485973  0.525144
# 160           SGDClassifier  0.525375   0.517817  0.511312  0.541581
# 161           MLPClassifier  0.558289   0.549865  0.559276  0.569771
# 162      LogisticRegression  0.579411   0.569980  0.582456  0.586291
# 163  RandomForestClassifier  0.515605   0.504194  0.491889  0.525159
# 164                     SVC  0.569754   0.563794  0.543131  0.586249
# 165    KNeighborsClassifier  0.542947   0.539988  0.470403  0.559812
# 166  DecisionTreeClassifier  0.508082   0.498514  0.485566  0.507651
# 167              GaussianNB  0.542341   0.528849  0.602165  0.564178
# 168              Perceptron  0.511915   0.507551  0.559569  0.496952
# 169           SGDClassifier  0.521605   0.517827  0.475074  0.518550
# 170           MLPClassifier  0.565315   0.558949  0.534017  0.583470
# 171      LogisticRegression  0.501875   0.493159  0.466291  0.536949
# 172  RandomForestClassifier  0.510345   0.503914  0.455576  0.526407
# 173                     SVC  0.541803   0.558144  0.345050  0.576002
# 174    KNeighborsClassifier  0.525681   0.517453  0.508333  0.519729
# 175  DecisionTreeClassifier  0.501452   0.492079  0.515915  0.501704
# 176              GaussianNB  0.543860   0.535338  0.537531  0.559417
# 177              Perceptron  0.498276   0.488591  0.447995  0.491904
# 178           SGDClassifier  0.510587   0.500665  0.469925  0.512572
# 179           MLPClassifier  0.575227   0.571890  0.555263  0.589511
#
# [180 rows x 9 columns]

# %%
non_fe = scores_df[scores_df['dict_type'] == "cumu_dfs_dict"]
yes_fe = scores_df[scores_df['dict_type'] == "ef_cumu_dfs_dict"]

# %%
print("The mean non-fe accuracy is: " + str(np.mean(non_fe['accuracy'])))
print("The mean fe accuracy is: " + str(np.mean(yes_fe['accuracy'])))
# Out:
# The mean non-fe accuracy is: 0.5313580019644094
# The mean fe accuracy is: 0.5309813223916977

# %%
scores_df.to_csv("../data/scores/hopt_scores_v3.csv")

# %%
# save dictionary using pickle
with open('../data/temp_data/hyperopt.pickle', 'wb') as handle:
    pickle.dump(scores_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('../data/temp_data/hyperopt.pickle', 'rb') as handle:
    hyperopt_dict = pickle.load(handle)

# %% [markdown]
# # Preliminary Analysis
# - The hyperparameters from the sklearn classifiers were set to their defaults and will be tuned.
#
#
# - Nevertheless, the effectiveness of each model appears to vary based off the length of the look back number. I will soon be transforming the printed text data above into nicer looking graphs.
#
#
# - Please scroll around in the above cell to view the accuracy, recall, precision, and ROC-AUC from using a cross validate method.
#
#
# - Now, most of the accuracy percentages are hovering near the 50% mark. As noted by previous literature, this data is inherently noisy and will likely make it very difficult to have an accuracy of over 60%. It is even more of an issue when generating the data using a look back window because the number of observations decreases substantially.

# %% [markdown]
# # Calculate Max Evals Required for each model

# %%
fe_cumu_1lb = data_dicts[1]['Cumulative Data: 1 Fight Lookback Window']
X,y = split_encode_standardize(fe_cumu_1lb)

# %%
max_evals_dict = {}
max_evals_dict['hyper_opt_par'] = []
max_evals_dict['model_name'] = []
max_evals_dict['accuracy'] = []
max_evals_dict['hp_dict'] = []

# %%
models = []

blr_clf = LogisticRegression()
rf_clf = RandomForestClassifier()
svm_clf = svm.SVC()
knn_clf = KNeighborsClassifier()
dtree_clf = DecisionTreeClassifier()
nb_clf = GaussianNB()
perc_clf = Perceptron()
sgd_clf = SGDClassifier()
mlp_clf = MLPClassifier()

# add models to a list
models.extend((blr_clf,rf_clf,svm_clf,knn_clf, dtree_clf, nb_clf, perc_clf, sgd_clf, mlp_clf))

# %%
for model in models:
    model_name = type(model).__name__

    print(model_name)

    space = get_space(model) # Get space

   # number_of_evals = get_max_evals(model_name) # get_max_evals from testing
    trials = Trials()
    best_h = fmin(fn=objective_function, space=space, algo=tpe.suggest, max_evals=30, trials = trials)
    
    # Plot accuracy over evaluations
    f, ax = plt.subplots(1)
    xs = [t['tid'] for t in trials.trials]
    ys = [1 - t['result']['loss'] for t in trials.trials]
    ax.scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
    ax.set_title(model_name + ' $Accuracy$ $vs$ $Trial Number$ ', fontsize=18)
    ax.set_xlabel('$trial number$', fontsize=16)
    ax.set_ylabel('$Accuracy$', fontsize=16)
    
    opt_hp = space_eval(space, best_h)

    max_evals_dict['hyper_opt_par'].append(opt_hp)

    print(opt_hp)
    del opt_hp['model']

    # create new model with tuned hyperparameters
    if model_name == "RandomForestClassifier":
        ht_model = RandomForestClassifier(**opt_hp)

    elif model_name == "KNeighborsClassifier":
        ht_model = KNeighborsClassifier(**opt_hp)

    elif model_name == "LogisticRegression":
        ht_model = LogisticRegression(**opt_hp)
    elif model_name == "SVC":
        ht_model = svm.SVC(**opt_hp)
    elif model_name == "DecisionTreeClassifier":
        ht_model = DecisionTreeClassifier(**opt_hp)
    elif model_name == "GaussianNB":
        ht_model = GaussianNB(**opt_hp)
    elif model_name == "Perceptron":
        ht_model = Perceptron(**opt_hp)
    elif model_name == "SGDClassifier":
        ht_model = SGDClassifier(**opt_hp)
    elif model_name == "MLPClassifier":
        ht_model = MLPClassifier(**opt_hp)




    scoring_stats = {'accuracy': 'accuracy',
           'recall': 'recall',
           'precision': 'precision',
           'roc_auc': 'roc_auc'}    



    # Calculate scores
    avg_scores = cross_validate(ht_model, X, y, cv=5, scoring = scoring_stats)

    accuracy = np.mean(avg_scores['test_accuracy'])


    # append to dictionary
    max_evals_dict['model_name'].append(model_name)
    max_evals_dict['accuracy'].append(accuracy)
    max_evals_dict['hp_dict'].append(opt_hp)
# Out:
# LogisticRegression
# 100%|██████████| 30/30 [00:37<00:00,  1.22s/it, best loss: 0.43201442158888437]
# {'dual': True, 'fit_intercept': False, 'model': 'LogisticRegression'}
# RandomForestClassifier
# 100%|██████████| 30/30 [04:03<00:00, 12.97s/it, best loss: 0.4058562609270304]
# {'max_depth': 6, 'max_features': 49, 'model': 'RandomForestClassifier', 'n_estimators': 32}
# SVC
# 100%|██████████| 30/30 [30:42<00:00, 61.96s/it, best loss: 0.421900696820391]
# {'kernel': 'rbf', 'model': 'SVC', 'shrinking': True}
# KNeighborsClassifier
#  20%|██        | 6/30 [06:23<25:20, 63.37s/it, best loss: 0.4446000602293736]

# %%
pd.DataFrame(max_evals_dict)
