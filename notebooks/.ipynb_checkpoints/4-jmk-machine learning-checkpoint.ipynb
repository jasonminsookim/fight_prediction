# %% [markdown]
# # 1. Import libraries, data, and globals

# %%
# %matplotlib inline

# Regular libraries
import requests
import pandas as pd
import string
import time
from bs4 import BeautifulSoup
from pandas.plotting import scatter_matrix
import os 
import string
import random
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Get rid of warnings
import warnings
warnings.filterwarnings('ignore')

# Sklearn Specific
from sklearn.model_selection import cross_val_score 
from sklearn.model_selection import cross_validate

# sklearn algos
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB # Naive Bayes
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier # SGD
from sklearn.neural_network import MLPClassifier # neural network (multilayer perceptron)

fs_df = pd.read_csv("../data/full_stats_v2.csv")
fc_df = pd.read_csv("../data/fighter_char.csv")
# Out:
# /anaconda3/envs/fight_prediction/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %% [markdown]
# # 2. Data wrangling

# %% [markdown]
# #### Add Totals

# %%
fs_df = fs_df.fillna(0) # Fill NaN with 0

# Calc time of fight in seconds
fs_df['duration'] = fs_df.apply(lambda x: (int(x['end_round'])-1)*60*5 + int(x['end_time'].split(":")[0])*60 + int(x['end_time'].split(":")[1]) , axis = 1)

# Calc totals for each fighter
which_fighter = ["f1","f2"]
stat_name_ending = ["kds","sigstrikes_l","sigstrikes_a","strikes_l","strikes_a","tds_l","tds_a","subs_a","passes",
                   "revs","ss_head_l","ss_head_a","ss_body_l","ss_body_a","ss_leg_l","ss_leg_a","ss_dist_l","ss_dist_a",
                   "ss_clinch_l","ss_clinch_a","ss_ground_l","ss_ground_a"]

for f in which_fighter:
    
    for stat in stat_name_ending:
        
        fs_df[f+'_t_' + stat] = np.sum(fs_df.loc[:,(fs_df.columns.str.startswith(f) & fs_df.columns.str.endswith(stat))], axis =1)
        
        fs_df[f+'_pm_' + stat] =  fs_df[f+'_t_' + stat] / fs_df['duration'] * 60

# %% [markdown]
# #### Subset the Data for Key Stats and Per Minute

# %%
matchers = ['fighter','winner',"_pm_","date"]
ml_cols = [s for s in fs_df.columns if any(xs in s for xs in matchers)]
ml_df = fs_df[ml_cols]

# %% [markdown]
# #### Make each fight have two rows, so that the label is win or lose

# %%
# Part 1
part_1_df = ml_df.copy()

part1_key_cols = part_1_df.columns
part1_value_cols = []

for col in part1_key_cols:
    new_col = col.replace("f1","f")
    new_col = new_col.replace("f2","o")
    new_col = new_col.replace("fighter_1","a_fighter")
    new_col = new_col.replace("fighter_2","a_opponent")
    new_col = new_col.replace("winner","a_winner")
    part1_value_cols.append(new_col)
    
p1_col_dict = dict(zip(part1_key_cols, part1_value_cols))

part_1_df = part_1_df.rename(columns = p1_col_dict)

# %%
# Part 2
part_2_df = ml_df.copy()

part2_key_cols = part_2_df.columns
part2_value_cols = []

for col in part2_key_cols:
    new_col = col.replace("f1","o")
    new_col = new_col.replace("f2","f")
    new_col = new_col.replace("fighter_1","a_opponent")
    new_col = new_col.replace("fighter_2","a_fighter")
    new_col = new_col.replace("winner","a_winner")
    part2_value_cols.append(new_col)
    
p2_col_dict = dict(zip(part2_key_cols, part2_value_cols))

part_2_df = part_2_df.rename(columns = p2_col_dict)

# %%
two_pf = pd.concat([part_1_df, part_2_df], sort = True)
two_pf = two_pf.sort_values(by ='date', ascending= False)
two_pf['result'] = two_pf.apply(lambda x: int(x['a_fighter'] == x['a_winner']), axis =1)

# %% [markdown]
# #### Show the wrangled and win/loss adjusted dataframe

# %%
two_pf.head(3)
# Out:
#                                  a_fighter                   a_opponent  \
# 0   Israel Adesanya "The Last Stylebender"  Anderson Silva "The Spider"
# 1                   Lando Vannata "Groovy"     Marcos Mariano "Dhalsim"
# 10              Jonathan Martinez "Dragon"  Wuliji Buren "Beast Master"
#
#                                   a_winner        date  f_pm_kds  f_pm_passes  \
# 0   Israel Adesanya "The Last Stylebender"  2019-02-09       0.0     0.000000
# 1                   Lando Vannata "Groovy"  2019-02-09       0.0     0.813559
# 10             Wuliji Buren "Beast Master"  2019-02-09       0.0     0.266667
#
#     f_pm_revs  f_pm_sigstrikes_a  f_pm_sigstrikes_l  f_pm_ss_body_a  ...  \
# 0    0.000000          11.733333           5.666667        0.933333  ...
# 1    0.000000          16.271186           8.135593        0.203390  ...
# 10   0.066667           5.800000           3.133333        0.533333  ...
#
#     o_pm_ss_head_a  o_pm_ss_head_l  o_pm_ss_leg_a  o_pm_ss_leg_l  \
# 0         5.266667        1.800000       2.066667       1.933333
# 1         7.525424        3.661017       0.406780       0.406780
# 10        4.266667        2.066667       1.600000       1.066667
#
#     o_pm_strikes_a  o_pm_strikes_l  o_pm_subs_a  o_pm_tds_a  o_pm_tds_l  \
# 0        14.920000        6.537778     0.000000         0.0    0.000000
# 1         6.270612        2.158001     0.000000         0.0    0.000000
# 10        9.657778        5.164444     0.066667         0.6    0.266667
#
#     result
# 0        1
# 1        1
# 10       0
#
# [3 rows x 49 columns]

# %%
two_pf.describe()
# Out:
#           f_pm_kds  f_pm_passes    f_pm_revs  f_pm_sigstrikes_a  \
# count  7434.000000  7434.000000  7434.000000        7434.000000
# mean      0.109153     0.155623     0.015604          10.523933
# std       0.512414     0.389497     0.117449           8.857232
# min       0.000000     0.000000     0.000000           0.000000
# 25%       0.000000     0.000000     0.000000           5.400000
# 50%       0.000000     0.000000     0.000000           8.517699
# 75%       0.000000     0.144928     0.000000          13.020113
# max       9.230769     9.600000     8.571429         137.142857
#
#        f_pm_sigstrikes_l  f_pm_ss_body_a  f_pm_ss_body_l  f_pm_ss_clinch_a  \
# count        7434.000000     7434.000000     7434.000000       7434.000000
# mean            4.787612        1.264215        0.861380          1.071830
# std             5.388737        1.149576        0.889993          2.052800
# min             0.000000        0.000000        0.000000          0.000000
# 25%             2.133333        0.524017        0.322725          0.133333
# 50%             3.582090        1.000000        0.666667          0.533927
# 75%             5.666667        1.666667        1.133333          1.266667
# max           112.000000       21.000000       18.000000         51.176471
#
#        f_pm_ss_clinch_l  f_pm_ss_dist_a  ...  o_pm_ss_head_a  o_pm_ss_head_l  \
# count       7434.000000     7434.000000  ...     7434.000000     7434.000000
# mean           0.736254        8.085448  ...        8.346284        3.209708
# std            1.431561        6.348670  ...        6.911298        3.761260
# min            0.000000        0.000000  ...        0.000000        0.000000
# 25%            0.066667        3.666667  ...        4.066667        1.266667
# 50%            0.335196        6.666667  ...        6.666667        2.233215
# 75%            0.866667       10.866667  ...       10.500000        3.800000
# max           35.294118       75.000000  ...       94.285714       56.250000
#
#        o_pm_ss_leg_a  o_pm_ss_leg_l  o_pm_strikes_a  o_pm_strikes_l  \
# count    7434.000000    7434.000000     7434.000000     7434.000000
# mean        0.913661       0.718150       37.801289       18.426116
# std         0.995655       0.805858       42.793170       28.338528
# min         0.000000       0.000000        0.000000        0.000000
# 25%         0.230843       0.166493       19.299867        8.239358
# 50%         0.659341       0.500000       28.897778       13.249778
# 75%         1.266667       1.000000       43.382521       20.069622
# max        22.000000      16.000000     1016.326531      792.000000
#
#        o_pm_subs_a   o_pm_tds_a   o_pm_tds_l       result
# count  7434.000000  7434.000000  7434.000000  7434.000000
# mean      0.079519     0.356855     0.137669     0.490987
# std       0.301374     0.510187     0.277029     0.499952
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.200000     0.000000     0.000000
# 75%       0.000000     0.527705     0.200000     1.000000
# max       8.571429     7.500000     7.500000     1.000000
#
# [8 rows x 45 columns]

# %% [markdown]
# # 3. Create cumulative statistics data with specified look back window

# %% [markdown]
# #### Create functions to make the look back window dataframe

# %%
def generate_fighters_dict():
    cols = two_pf.columns.tolist()
    fighters = {}
    for index, row in two_pf.iterrows():
        fighter = row["a_fighter"]
        if fighter not in fighters:
            fighters[fighter] = [row]
        else:
            fighters[fighter].append(row)
    for fighter in fighters:
        rows_list = fighters[fighter]
        fighters[fighter] = pd.DataFrame(columns=cols, data=rows_list)
    return fighters

fighters_dict = generate_fighters_dict() # Generates a dictionary with each fighter having his own pd.DataFrame()

# %%
def get_fighter_info(past_df, is_fighter, lb_num):
    latest_df = past_df.head(lb_num)
    latest_lb_cum = latest_df.mean(skipna=True, numeric_only=True).to_dict()
    new_dict = {}
    if is_fighter:
        for var in latest_lb_cum:
            if var[0] == "f":
                new_dict[var] = latest_lb_cum[var]
    else:
        for var in latest_lb_cum:
            if var[0] == "f":
                new_var = var.replace("f_", "o_")
                new_dict[new_var] = latest_lb_cum[var]
    return new_dict

def generate_cum_df(fighters_dict, lb_num):
    
    cumulative_df = pd.DataFrame(columns = two_pf.columns)
    counter = 1
    
    for index, row in two_pf.iterrows():
        fighter_name = row["a_fighter"]
        opponent_name = row["a_opponent"]
        fight_date = row["date"]
        
        fighter_df = fighters_dict[fighter_name]
        opponent_df = fighters_dict[opponent_name]
        
        past_fighter_df = fighter_df.loc[fighter_df['date'] < fight_date]
        if past_fighter_df.shape[0] < lb_num:
            continue
        past_opponent_df = opponent_df.loc[opponent_df['date'] < fight_date]
        if past_opponent_df.shape[0] < lb_num:
            continue
        fighter_info = get_fighter_info(past_fighter_df, True, lb_num)
        opponent_info = get_fighter_info(past_opponent_df, False, lb_num)
        all_info = dict(fighter_info, **opponent_info)
        all_info['a_fighter'] = row['a_fighter']
        all_info['a_opponent'] = row['a_opponent']
        all_info['a_winner'] = row['a_winner']
        all_info['date'] = row['date']
        all_info['result'] = row['result']
        
        all_info_df = pd.DataFrame(all_info, index=[0])
        
        cumulative_df = pd.concat([cumulative_df, all_info_df])
        
    return(cumulative_df)

# %% [markdown]
# #### Make cumulative data

# %%
cumu_3_df = generate_cum_df(fighters_dict,3)    
cumu_5_df = generate_cum_df(fighters_dict,5)

# %% [markdown]
# # Generate machine learning models

# %%
# Split features and labels
X = two_pf.iloc[:,4:-1]
y = two_pf['result']

# %%
models = []

blr_clf = LogisticRegression()
rf_clf = RandomForestClassifier()
svm_clf = svm.SVC()
knn_clf = KNeighborsClassifier()
dtree_clf = DecisionTreeClassifier()
nb_clf = GaussianNB()
perc_clf = Perceptron()
sgd_clf = SGDClassifier()
mlp_clf = MLPClassifier()

models.extend((blr_clf ,rf_clf, svm_clf, knn_clf, dtree_clf, nb_clf, perc_clf, sgd_clf,mlp_clf))

# %% [markdown]
# # Train and print scores for each model

# %%
for model in models:
    print(model)
    scoring = {'accuracy': 'accuracy',
           'recall': 'recall',
           'precision': 'precision',
           'roc_auc': 'roc_auc'}
    
    model.fit(X, y)
    avg_scores = cross_validate(model, X, y, cv=10, scoring= scoring)
    print(avg_scores.keys())
    print("Accuracy: " + str(np.mean(avg_scores['test_accuracy'])))
    print("Recall:" + str(np.mean(avg_scores['test_recall'])))
    print("Precision:" + str(np.mean(avg_scores['test_precision'])))
    print("ROC - AUC:" + str(np.mean(avg_scores['test_roc_auc'])))
    print("\n \n")
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# dict_keys(['fit_time', 'score_time', 'test_accuracy', 'train_accuracy', 'test_recall', 'train_recall', 'test_precision', 'train_precision', 'test_roc_auc', 'train_roc_auc'])
# Accuracy: 0.9667746638880447
# Recall:0.9706849315068492
# Precision:0.9620926635128277
# ROC - AUC:0.9877099300582148
#
#
#
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# dict_keys(['fit_time', 'score_time', 'test_accuracy', 'train_accuracy', 'test_recall', 'train_recall', 'test_precision', 'train_precision', 'test_roc_auc', 'train_roc_auc'])
# Accuracy: 0.9490153620168164
# Recall:0.9358904109589041
# Precision:0.9593916349170607
# ROC - AUC:0.9842662127038823
#
#
#
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# dict_keys(['fit_time', 'score_time', 'test_accuracy', 'train_accuracy', 'test_recall', 'train_recall', 'test_precision', 'train_precision', 'test_roc_auc', 'train_roc_auc'])
# Accuracy: 0.9219789721993081
# Recall:0.8871232876712328
# Precision:0.9507187612459097
# ROC - AUC:0.9739511677331102
#
#
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')
# dict_keys(['fit_time', 'score_time', 'test_accuracy', 'train_accuracy', 'test_recall', 'train_recall', 'test_precision', 'train_precision', 'test_roc_auc', 'train_roc_auc'])
# Accuracy: 0.9365055934239281
# Recall:0.9413698630136986
# Precision:0.9302419059627637
# ROC - AUC:0.9750627120002189
#
#
#
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# dict_keys(['fit_time', 'score_time', 'test_accuracy', 'train_accuracy', 'test_recall', 'train_recall', 'test_precision', 'train_precision', 'test_roc_auc', 'train_roc_auc'])
# Accuracy: 0.9015293274866497
# Recall:0.8972602739726028
# Precision:0.9017626399834867
# ROC - AUC:0.9014550312359976
#
#
#
# GaussianNB(priors=None)
# dict_keys(['fit_time', 'score_time', 'test_accuracy', 'train_accuracy', 'test_recall', 'train_recall', 'test_precision', 'train_precision', 'test_roc_auc', 'train_roc_auc'])
# Accuracy: 0.8112619213013215
# Recall:0.8084931506849315
# Precision:0.8078222578999181
# ROC - AUC:0.8844409237371973
#
#
#
# Perceptron(alpha=0.0001, class_weight=None, eta0=1.0, fit_intercept=True,
#       max_iter=None, n_iter=None, n_jobs=1, penalty=None, random_state=0,
#       shuffle=True, tol=None, verbose=0, warm_start=False)
# dict_keys(['fit_time', 'score_time', 'test_accuracy', 'train_accuracy', 'test_recall', 'train_recall', 'test_precision', 'train_precision', 'test_roc_auc', 'train_roc_auc'])
# Accuracy: 0.9647565449572353
# Recall:0.9676712328767124
# Precision:0.9608733343921931
# ROC - AUC:0.9870309422548551
#
#
#
# SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', max_iter=None, n_iter=None,
#        n_jobs=1, penalty='l2', power_t=0.5, random_state=None,
#        shuffle=True, tol=None, verbose=0, warm_start=False)
# dict_keys(['fit_time', 'score_time', 'test_accuracy', 'train_accuracy', 'test_recall', 'train_recall', 'test_precision', 'train_precision', 'test_roc_auc', 'train_roc_auc'])
# Accuracy: 0.9604496808926324
# Recall:0.9602739726027398
# Precision:0.9594149106110738
# ROC - AUC:0.9860809632624431
#
#
#
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# dict_keys(['fit_time', 'score_time', 'test_accuracy', 'train_accuracy', 'test_recall', 'train_recall', 'test_precision', 'train_precision', 'test_roc_auc', 'train_roc_auc'])
# Accuracy: 0.9675809346010796
# Recall:0.9778082191780821
# Precision:0.957119728165895
# ROC - AUC:0.9891326438407798

# %% [markdown]
# # Preliminary Analysis
#
# - These models are using the statistics from night of the fight, which will have hindsight bias. Consequently, the accuracy, precision, and recall listed here is much higher than what should be expected with cumulative data.
#
# - The hyperparameters from the sklearn classifiers were set to their defaults. These hyperparameters may be tuned once the cumulative data generation is completed.
#
# - Nevertheless, the LogisticRegression, Random Forrest, Perceptron, SGDClassifier, and MLPClassifier appear to be the most promising in terms of highest accuracy %. In fact, the MLPClassifier looks to be the most promising model so far, which has not been used in the academic literature yet.
#
# - Please scroll around in the above cell to view the accuracy, recall, precision, and ROC-AUC from using a cross validate method.

# %% [markdown]
# # (WIP) Making Cumulative Data
#
# - This has been the most challenging part of the data manipulation.
# - I want to create a function that allows the lookback window to vary by number of fights. This will allow for a comparison of varying lookback windows and how they effect the models.
# - Once this part of the project is done, it will be extremely easy and fast to iteratively update the models.
# - The code below is scratch work for this section.
#
# - Additionally, the fighter's age, height, and reach has already been scraped and will be merged into the cumulative data by fighter names.

# %%
def generate_fighters_dict():
    cols = two_pf.columns.tolist()
    fighters = {}
    for index, row in two_pf.iterrows():
        fighter = row["a_fighter"]
        if fighter not in fighters:
            fighters[fighter] = [row]
        else:
            fighters[fighter].append(row)
    for fighter in fighters:
        rows_list = fighters[fighter]
        fighters[fighter] = pd.DataFrame(columns=cols, data=rows_list)
    return fighters

fighters_dict = generate_fighters_dict()

# %%
def get_fighter_info(past_df, is_fighter, lb_num):
    latest_df = past_df.head(lb_num)
    latest_lb_cum = latest_df.mean(skipna=True, numeric_only=True).to_dict()
    new_dict = {}
    if is_fighter:
        for var in latest_lb_cum:
            if var[0] == "f":
                new_dict[var] = latest_lb_cum[var]
    else:
        for var in latest_lb_cum:
            if var[0] == "f":
                new_var = var.replace("f_", "o_")
                new_dict[new_var] = latest_lb_cum[var]
    return new_dict

def generate_cum_df(fighters_dict, lb_num):
    
    cumulative_df = pd.DataFrame(columns = two_pf.columns)
    counter = 1
    
    for index, row in two_pf.iterrows():
        fighter_name = row["a_fighter"]
        opponent_name = row["a_opponent"]
        fight_date = row["date"]
        
        fighter_df = fighters_dict[fighter_name]
        opponent_df = fighters_dict[opponent_name]
        
        past_fighter_df = fighter_df.loc[fighter_df['date'] < fight_date]
        if past_fighter_df.shape[0] < lb_num:
            continue
        past_opponent_df = opponent_df.loc[opponent_df['date'] < fight_date]
        if past_opponent_df.shape[0] < lb_num:
            continue
        fighter_info = get_fighter_info(past_fighter_df, True, lb_num)
        opponent_info = get_fighter_info(past_opponent_df, False, lb_num)
        all_info = dict(fighter_info, **opponent_info)
        all_info['a_fighter'] = row['a_fighter']
        all_info['a_opponent'] = row['a_opponent']
        all_info['a_winner'] = row['a_winner']
        all_info['date'] = row['date']
        all_info['result'] = row['result']
        
        all_info_df = pd.DataFrame(all_info, index=[0])
        
        cumulative_df = pd.concat([cumulative_df, all_info_df])
        
    return(cumulative_df)
# Out:
#                                      a_fighter  \
# 0       Israel Adesanya "The Last Stylebender"
# 0                  Kyung Ho Kang "Mr. Perfect"
# 0                  Anderson Silva "The Spider"
# 0                    Teruto Ishihara "Yashabo"
# 0                     Renato Moicano "Moicano"
# 0                  Charles Oliveira "Do Bronx"
# 0                        Marlon Moraes "Magic"
# 0                          Lyman Good "Cyborg"
# 0                                    Jose Aldo
# 0                                 David Teymur
# 0                           Max Griffin "Pain"
# 0                             Raphael Assuncao
# 0                                  Demian Maia
# 0                       Thiago Alves "Pitbull"
# 0                 Henry Cejudo "The Messenger"
# 0                  Gregor Gillespie "The Gift"
# 0                             Joseph Benavidez
# 0                              Glover Teixeira
# 0                                 TJ Dillashaw
# 0                               Yancy Medeiros
# 0                                 Dustin Ortiz
# 0                       Karl Roberson "Baby K"
# 0                         Cris Cyborg "Cyborg"
# 0                       Amanda Nunes "Lioness"
# 0                 Walt Harris "The Big Ticket"
# 0            Alexander Volkanovski "The Great"
# 0                    Corey Anderson "Overtime"
# 0                    Michael Chiesa "Maverick"
# 0            Alexander Gustafsson "The Mauler"
# 0               Ilir Latifi "The Sledgehammer"
# ..                                         ...
# 0                    Rory MacDonald "Red King"
# 0            Alexander Gustafsson "The Mauler"
# 0                             Rafael Dos Anjos
# 0                          George Sotiropoulos
# 0             Charlie Brenneman "The Spaniard"
# 0     0.198020       0
# 0     0.249591       1
# 0     0.066667       1
# 0     0.318376       0
# 0     0.109689       0
# 0     0.000000       0
# 0     0.133333       0
# 0     0.407843       0
# 0     0.000000       1
# 0     0.066667       1
# 0     0.111111       1
# 0     0.282649       0
# 0     0.044444       1
# 0     0.150116       1
# 0     0.000000       0
#
# [2706 rows x 49 columns]

# %%
cumu_3_df = generate_cum_df(fighters_dict,3)    
cumu_5_df = generate_cum_df(fighters_dict,5)

# %%
print(cumu_3_df.shape)
# Out:
# (2706, 49)

# %%
print(cumu_5_df.shape)
# Out:
# (1498, 49)

# %%
fighters_dict['Marcos Mariano "Dhalsim"'].shape[0]
# Out:
# 1

# %%
hmm = two_pf.loc[two_pf['a_fighter'] == 'Marcos Mariano "Dhalsim"']
shape = hmm.shape

# %%
shape

# %%
def generate_fighters_dict():
    cols = two_pf.columns.tolist()
    fighters = {}
    for index, row in two_pf.iterrows():
        fighter = row["a_fighter"]
        if fighter not in fighters:
            fighters[fighter] = [row]
        else:
            fighters[fighter].append(row)
    for fighter in fighters:
        rows_list = fighters[fighter]
        fighters[fighter] = pd.DataFrame(columns=cols, data=rows_list)
    return fighters

fighters_dict = generate_fighters_dict()

# %%
def get_fighter_info(past_df, is_fighter, lb_num):
    latest_df = past_df.head(lb_num)
    latest_lb_cum = latest_df.mean(skipna=True, numeric_only=True).to_dict()
    new_dict = {}
    if is_fighter:
        for var in latest_lb_cum:
            if var[0] == "f":
                new_dict[var] = latest_lb_cum[var]
    else:
        for var in latest_lb_cum:
            if var[0] == "o":
                new_dict[var] = latest_lb_cum[var]
    return new_dict

def generate_cum_df(fighters_dict, lb_num):
    
    cumulative_df = pd.DataFrame(columns = two_pf.columns)
    counter = 1
    
    for index, row in two_pf.iterrows():
        fighter_name = row["a_fighter"]
        opponent_name = row["a_opponent"]
        fight_date = row["date"]
        fighter_df = fighters_dict[fighter_name]
        opponent_df = fighters_dict[opponent_name]
        past_fighter_df = fighter_df.loc[fighter_df['date'] < fight_date]
        if past_fighter_df.shape[0] < lb_num:
            continue
        past_opponent_df = opponent_df.loc[opponent_df['date'] < fight_date]
        if past_fighter_df.shape[0] < lb_num:
            continue
        fighter_info = get_fighter_info(past_fighter_df, True, lb_num)
        opponent_info = get_fighter_info(past_opponent_df, False, lb_num)
        all_info = dict(fighter_info)
        all_info.update(opponent_info)
        all_info['a_fighter'] = row['a_fighter']
        all_info['a_opponent'] = row['a_opponent']
        all_info['a_winner'] = row['a_winner']
        all_info['date'] = row['date']
        all_info['result'] = row['result']
        
        # Fix this shit
        all_info_df = pd.DataFrame(all_info, index=[0])
        
        #cumulative_df.append(all_info_df, ingore_index = True)
        
        counter += 1
        if counter == 3: 
            return(all_info_df)
        
final_df = generate_cum_df(fighters_dict,3)

# %%
final_df.to_csv("test_df.csv")

# %%
test_df = pd.read_csv("test_df.csv")
test_df
# Out:
#    Unnamed: 0  f_pm_kds  f_pm_passes  f_pm_revs  f_pm_sigstrikes_a  \
# 0           0  0.088889     0.066667        0.0          14.133333
#
#    f_pm_sigstrikes_l  f_pm_ss_body_a  f_pm_ss_body_l  f_pm_ss_clinch_a  \
# 0           6.022222        1.688889        0.955556          1.555556
#
#    f_pm_ss_clinch_l   ...    o_pm_strikes_a  o_pm_strikes_l  o_pm_subs_a  \
# 0          1.244444   ...               NaN             NaN          NaN
#
#    o_pm_tds_a  o_pm_tds_l               a_fighter                a_opponent  \
# 0         NaN         NaN  Lando Vannata "Groovy"  Marcos Mariano "Dhalsim"
#
#                  a_winner        date  result
# 0  Lando Vannata "Groovy"  2019-02-09       1
#
# [1 rows x 50 columns]

# %%
def make_data(df, lb_period):
    
    r_df = pd.DataFrame()
    for index,row in df.iterrows():
        
        r_row = []
        
        fighter_name = row["a_fighter"]
        opponent_name = row["a_opponent"]
        fight_date = row["date"]
        
        
        
        break

# %%
final_df

# %%
cum_df = pd.DataFrame(data=None, columns=two_pf.columns)
cum_df
# Out:
# Empty DataFrame
# Columns: [a_fighter, a_opponent, a_winner, date, f_pm_kds, f_pm_passes, f_pm_revs, f_pm_sigstrikes_a, f_pm_sigstrikes_l, f_pm_ss_body_a, f_pm_ss_body_l, f_pm_ss_clinch_a, f_pm_ss_clinch_l, f_pm_ss_dist_a, f_pm_ss_dist_l, f_pm_ss_ground_a, f_pm_ss_ground_l, f_pm_ss_head_a, f_pm_ss_head_l, f_pm_ss_leg_a, f_pm_ss_leg_l, f_pm_strikes_a, f_pm_strikes_l, f_pm_subs_a, f_pm_tds_a, f_pm_tds_l, o_pm_kds, o_pm_passes, o_pm_revs, o_pm_sigstrikes_a, o_pm_sigstrikes_l, o_pm_ss_body_a, o_pm_ss_body_l, o_pm_ss_clinch_a, o_pm_ss_clinch_l, o_pm_ss_dist_a, o_pm_ss_dist_l, o_pm_ss_ground_a, o_pm_ss_ground_l, o_pm_ss_head_a, o_pm_ss_head_l, o_pm_ss_leg_a, o_pm_ss_leg_l, o_pm_strikes_a, o_pm_strikes_l, o_pm_subs_a, o_pm_tds_a, o_pm_tds_l, result]
# Index: []
#
# [0 rows x 49 columns]

# %%
for index, row in two_pf.iterrows():
    fighter_name = row['a_fighter']
    fight_date = row['date']
    fighter_df = two_pf.loc[two_pf['a_fighter'] == fighter_name] 
    past_df = fighter_df.loc[fighter_df['date'] < fight_date]
    
    cum_series = past_df.mean()
    
    cum_keys = cum_series.keys().tolist()
    cum_values = []
    cum_values = cum_series.tolist()
    
    cum_values =[fighter_name] + [row['a_opponent']] + [row['a_winner']] + [fight_date] + cum_values 
    print(len(cum_values))
    if len(cum_values) == 53:
        print("cum_keys:",len(cum_keys))
        print(cum_values)
    cum_df.append(cum_values)
    
    if index == 3:
        break
# Out:
# 49
# 49
# 49
# 49
# 49
# 53
# cum_keys: 49
# ['Raulian Paiva', 'Kai Kara-France "Don\'t Blink"', 'Kai Kara-France "Don\'t Blink"', '2019-02-09', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]
# 49
# 49
# 49
# 49
