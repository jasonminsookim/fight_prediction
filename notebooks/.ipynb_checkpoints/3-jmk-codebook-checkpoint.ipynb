# %%
import pandas as pd

# %%
stats_df = pd.read_csv("full_stats.csv")

# %%
variable_ids = list(stats_df.columns)

# %%
variable_ids[6]
# Out:
# 'f1_r1_kds'

# %%
variable_labels = []
var_to_label = {
    "fighter": "fighter",
    "1": "1",
    "2": "2",
    "l": "landed",
    "a": "attempts",
    "f1": "fighter 1",
    "f2": "fighter 2",
    "r1": "round 1",
    "r2": "round 2",
    "r3": "round 3",
    "r4": "round 4",
    "r5": "round 5",
    "kds": "knockdowns",
    "sigstrikes": "significant strikes",
    "tds": "takedowns",
    "subs": "submissions",
    "rev": "reversals",
    "ss": "significant strikes",
    "head": "to the head",
    "body": "to the body",
    "leg": "to the leg",
    "distance": "from distance",
    "clinch": "from clinch",
    "ground": "from ground"
}

for col in variable_ids:
    col_vars = col.split("_")
    for var in col_vars:
        var_to_append = var_to_label[var] if var in var_to_label else var
        col_labels.append(var_to_append)
    label = " ".join(col_labels)
    variable_labels.append(label)

print(len(variable_labels))

    
#     if col == "fighter_1":
#         variable_labels.append("fighter 1")
#     elif col == "fighter_2":
#         variable_labels.append("fighter 2")
#     elif col == "winner":
#         variable_labels.append("winner")
#     elif(col[0:2] == "f1" or col[0:2] == "f2"):
#         temp_word = col.replace("l","landed").replace("a","attempts")
#         temp_word = temp_word.replace("f1","fighter 1").replace("f2","fighter 2")
#         temp_word = temp_word.replace("r1","round 1").replace("r2","round 2").replace("r3","round 3").replace("r4","round 4").replace("r5","round 5")
#         temp_word = temp_word.replace("kds", "knockdowns").replace("sigstrikes","significant strikes")
#         temp_word = temp_word.replace("tds", "takedowns").replace("subs","submissions").replace("rev","reversals")
#         temp_word = temp_word.replace("ss_head","significant strikes to the head").replace("ss_body","significant strikes to the body")
#         temp_word = temp_word.replace("ss_leg","significant strikes to the leg").replace("ss_distance","significant strikes from distance")
#         temp_word = temp_word.replace("ss_clinch","significant strikes from clinch").replace("ss_ground","significant strikes from ground").replace("_"," ")


#         variable_labels.append(temp_word)
    
#     else:
#         variable_labels.append(col)
# Out:
# 226

# %%
code_book = pd.DataFrame({"Variable IDs":variable_ids, "Variable Labels": variable_labels})

# %%
code_book
# Out:
#            Variable IDs                                    Variable Labels
# 0            Unnamed: 0  fighter 2 round 5 significant strikes from gro...
# 1             fighter_1  fighter 2 round 5 significant strikes from gro...
# 2             fighter_2  fighter 2 round 5 significant strikes from gro...
# 3                winner  fighter 2 round 5 significant strikes from gro...
# 4                   url  fighter 2 round 5 significant strikes from gro...
# 5                  date  fighter 2 round 5 significant strikes from gro...
# 6             f1_r1_kds  fighter 2 round 5 significant strikes from gro...
# 7    f1_r1_sigstrikes_l  fighter 2 round 5 significant strikes from gro...
# 8    f1_r1_sigstrikes_a  fighter 2 round 5 significant strikes from gro...
# 9       f1_r1_strikes_l  fighter 2 round 5 significant strikes from gro...
# 10      f1_r1_strikes_a  fighter 2 round 5 significant strikes from gro...
# 11          f1_r1_tds_l  fighter 2 round 5 significant strikes from gro...
# 12          f1_r1_tds_a  fighter 2 round 5 significant strikes from gro...
# 13         f1_r1_subs_a  fighter 2 round 5 significant strikes from gro...
# 14         f1_r1_passes  fighter 2 round 5 significant strikes from gro...
# 15           f1_r1_revs  fighter 2 round 5 significant strikes from gro...
# 16      f1_r1_ss_head_l  fighter 2 round 5 significant strikes from gro...
# 17      f1_r1_ss_head_a  fighter 2 round 5 significant strikes from gro...
# 18      f1_r1_ss_body_l  fighter 2 round 5 significant strikes from gro...
# 19      f1_r1_ss_body_a  fighter 2 round 5 significant strikes from gro...
# 20       f1_r1_ss_leg_l  fighter 2 round 5 significant strikes from gro...
# 21       f1_r1_ss_leg_a  fighter 2 round 5 significant strikes from gro...
# 22      f1_r1_ss_dist_l  fighter 2 round 5 significant strikes from gro...
# 23      f1_r1_ss_dist_a  fighter 2 round 5 significant strikes from gro...
# 24    f1_r1_ss_clinch_l  fighter 2 round 5 significant strikes from gro...
# 25    f1_r1_ss_clinch_a  fighter 2 round 5 significant strikes from gro...
# 26    f1_r1_ss_ground_l  fighter 2 round 5 significant strikes from gro...
# 27    f1_r1_ss_ground_a  fighter 2 round 5 significant strikes from gro...
# 28            f2_r1_kds  fighter 2 round 5 significant strikes from gro...
# 29   f2_r1_sigstrikes_l  fighter 2 round 5 significant strikes from gro...
# ..                  ...                                                ...
# 196      f1_r5_ss_leg_l  fighter 2 round 5 significant strikes from gro...
# 197      f1_r5_ss_leg_a  fighter 2 round 5 significant strikes from gro...
# 198     f1_r5_ss_dist_l  fighter 2 round 5 significant strikes from gro...
# 199     f1_r5_ss_dist_a  fighter 2 round 5 significant strikes from gro...
# 200   f1_r5_ss_clinch_l  fighter 2 round 5 significant strikes from gro...
# 201   f1_r5_ss_clinch_a  fighter 2 round 5 significant strikes from gro...
# 202   f1_r5_ss_ground_l  fighter 2 round 5 significant strikes from gro...
# 203   f1_r5_ss_ground_a  fighter 2 round 5 significant strikes from gro...
# 204           f2_r5_kds  fighter 2 round 5 significant strikes from gro...
# 205  f2_r5_sigstrikes_l  fighter 2 round 5 significant strikes from gro...
# 206  f2_r5_sigstrikes_a  fighter 2 round 5 significant strikes from gro...
# 207     f2_r5_strikes_l  fighter 2 round 5 significant strikes from gro...
# 208     f2_r5_strikes_a  fighter 2 round 5 significant strikes from gro...
# 209         f2_r5_tds_l  fighter 2 round 5 significant strikes from gro...
# 210         f2_r5_tds_a  fighter 2 round 5 significant strikes from gro...
# 211        f2_r5_subs_a  fighter 2 round 5 significant strikes from gro...
# 212        f2_r5_passes  fighter 2 round 5 significant strikes from gro...
# 213          f2_r5_revs  fighter 2 round 5 significant strikes from gro...
# 214     f2_r5_ss_head_l  fighter 2 round 5 significant strikes from gro...
# 215     f2_r5_ss_head_a  fighter 2 round 5 significant strikes from gro...
# 216     f2_r5_ss_body_l  fighter 2 round 5 significant strikes from gro...
# 217     f2_r5_ss_body_a  fighter 2 round 5 significant strikes from gro...
# 218      f2_r5_ss_leg_l  fighter 2 round 5 significant strikes from gro...
# 219      f2_r5_ss_leg_a  fighter 2 round 5 significant strikes from gro...
# 220     f2_r5_ss_dist_l  fighter 2 round 5 significant strikes from gro...
# 221     f2_r5_ss_dist_a  fighter 2 round 5 significant strikes from gro...
# 222   f2_r5_ss_clinch_l  fighter 2 round 5 significant strikes from gro...
# 223   f2_r5_ss_clinch_a  fighter 2 round 5 significant strikes from gro...
# 224   f2_r5_ss_ground_l  fighter 2 round 5 significant strikes from gro...
# 225   f2_r5_ss_ground_a  fighter 2 round 5 significant strikes from gro...
#
# [226 rows x 2 columns]
